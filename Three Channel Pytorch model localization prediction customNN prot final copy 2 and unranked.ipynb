# %% [markdown]
# # Training (Protein)

# %% [markdown]
# #### Last edit 7/20/2025, for unranked

# %% [markdown]
# ## Set up

# %% [markdown]
# ### Package imports

# %%
# Import packages
import os
import copy
from pathlib import Path
import numpy as np
from numpy.random import MT19937
from numpy.random import RandomState, SeedSequence
import pandas as pd
import random
from pdb import set_trace

import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import seaborn as sns

from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, matthews_corrcoef

import torch
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

# %% [markdown]
# ### GPU

# %%
# Check to see if the GPU is available and store it as a variable so tensors can be moved to it
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print('Is cuda available?:', torch.cuda.is_available())
print('cuda version:', torch.version.cuda)
dev = "cuda:0"
# Out:
# Using device: cuda
# Is cuda available?: True
# cuda version: 11.7

# %% [markdown]
# ### Variables and Hyperparameters

# %%
# Create run name
Run_Name = 'Prot' # change run_name before running

# Paths
label_path = '/home/ec2-user/Jul2025/labels/' # label folder with all the labels
dataset_folder_path = '/home/ec2-user/Jul2025/processed_dataset3/' # dataset folder with all the processed proteome and mRNA data
model_folder_path = '/home/ec2-user/Jul2025/saved_models/' # model folder with all the models
fig_bank_path = '/home/ec2-user/Jul2025/NN_figure_bank/' # figure bank folder with all the figures
cv_folder_path = '/home/ec2-user/Jul2025/NN_CV_bank/' # cross-validation folder with all the cross-validation results

# Define the Model
Model = 'PixelPreserve' # 'PixelPreserve' are the options

# Dataset
Set = 'Protein' # Define the dataset to use, 'Protein', 'mRNA', or 'Protein + mRNA' are the options

# Image size
Canvas_Size = 18

# Seed number
Seed = 43

# Validation fraction
Validation_Fraction = 0.2

# Standard deviation for add-noise transformation
StandardDeviation = 0.005 # 0.005 so far is better

# Learning rate scheduler
Learner_rate = 1e-4

# Optimizer
Weight_Decay = 0.0001 # L2 regulator
#  it works by adding a penalty to the loss function, which discourages large weights in the model; penalizes for too many weights - helps prevent overfitting
#  the penalty is calculated as weight_decay * weight^2, and it's added to the loss.
#  1e-4 or 1e-3 gives higher acc

# Batch size
Batch_size = 64

# Epoch amount
epochs = 100

# %% [markdown]
# ### Protein, mRNA dataframe, localization label set up

# %%
# Open the proteomics data and only keep genes (rows) that are fully quantified
PFP = 'K_PD_synthetic_kde_june.csv' # synthetic data
PD = pd.read_csv(dataset_folder_path+PFP)

# Data set wrangling
PD.index = PD.loc[:,'Index']
PD = PD.loc[:,PD.columns!='Index']
PD.dropna(inplace=True)

# Open the mRNA data and only keep genes (rows) that are fully quantified
MFP = 'K_MD_synthetic_kde_june.csv'
MD = pd.read_csv(dataset_folder_path + MFP)

# Data set wrangling
MD.index = MD.loc[:,'Index']
MD = MD.loc[:,MD.columns!='Index']
MD = MD.drop_duplicates()
MD.dropna(inplace=True)

# %%
# Open the labels data
LFP = 'markers.txt'
LD = pd.read_csv(filepath_or_buffer=label_path+LFP,sep='\t')
# Data set wrangling
LD.index = LD.loc[:,'Protein']
LD = LD.loc[:,LD.columns!='Protein']

# %%
# Select the localization labels that are both common in the proteomics and mRNA data
common_genes = set(PD.index).intersection(set(MD.index))
# Select only the common genes
LD = LD.loc[LD.index.isin(common_genes),:]

print('Number of total labels in Krug dataset')
print(len(LD.index))
print(LD['Localization'].value_counts())
# Out:
# Number of total labels in Krug dataset
# 2693
# Localization
# Cytosol         1036
# Secretory        769
# Nucleus          624
# Mitochondria     264
# Name: count, dtype: int64

# %% [markdown]
# ### Set seed function

# %%
def set_seed(seed):
    random.seed(seed) # set random seed for python
    np.random.seed(seed) # set random seed for numpy
    torch.manual_seed(seed) # set random seed for CPU
    rs = RandomState(MT19937(SeedSequence(seed))) # seed for numpy
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed) # set random seed for all GPUs
    torch.backends.cudnn.deterministic = True # set to True to get reproducible results
    torch.backends.cudnn.benchmark = False # set to False to get reproducible results

# %% [markdown]
# ### Pixel coordinates and RGB tensor generation functions

# %%
def gen_horizontal_coords(n, num_points):
    """
    Generate coordinates for a horizontal pattern starting from the top-left corner.

    Parameters:
    n (int): Size of the canvas (n x n).
    num_points (int): Number of points to generate in the horizontal pattern.

    Returns:
    list: List of (x, y) coordinates in horizontal order.
    """
    coords = [(x, y) for x in range(n) for y in range(n)]
    return coords[:num_points]

def create_rgb_tensors(set, interleaved_array):
    """
    Create RGB tensors from abundance data using the specified pattern.
    
    Parameters:
    set (str): Dataset used for plotting ('Protein', 'mRNA', 'Protein + mRNA').
    df1 (pd.DataFrame): DataFrame containing normalized abundance data.
    df2 (pd.DataFrame): DataFrame containing normalized abundance data.
    
    Returns:
    torch.Tensor: RGB tensor.
    """

    interleaved_array = interleaved_array.flatten()
    num_pixels = len(interleaved_array)
    
    # Generate coordinates based on the pattern, spiral or horizontal arrangment
    coords = gen_horizontal_coords(Canvas_Size, num_pixels)

    # Create RGB tensor
    rgb_tensor = np.zeros((Canvas_Size, Canvas_Size, 3), dtype=np.float32)
    for i, (x, y) in enumerate(coords):
        if i < len(interleaved_array):
            value = interleaved_array[i]
            # Assign colors based on the value, if abundance > 1, set it to red, if abundance < 0, set it to blue.
            #if value > 1:
            #    rgb_tensor[x, y] = [255, 0, 0]  # Red for value > 1
            #elif value < 0:
            #    rgb_tensor[x, y] = [0, 0, 255]  # Blue for value < 0
            #else:
            rgb_tensor[x, y] = [255 * value, 0, 255 * (1 - value)]

    return torch.from_numpy(rgb_tensor.transpose(2, 0, 1))  # Convert to CHW format for PyTorch

# %% [markdown]
# ### Custom Transformation

# %%
# Custom transformation to add noise to the data
class AddNoise:
    def __init__(self, set, mean=0, std=0.005):
        self.set = set
        self.mean = mean
        self.std = std

    def __call__(self, array1, array2):
        if self.set == 'Protein + mRNA':
            noise1 = np.random.normal(self.mean, self.std, array1.shape)
            noise2 = np.random.normal(self.mean, self.std, array2.shape)

            return array1 + noise1, array2 + noise2    

        else: # suitable for Protein or mRNA only because same noise will be applied twice
            noise = np.random.normal(self.mean, self.std, array1.shape)
        
        return array1 + noise, array2 + noise

# %% [markdown]
# ### Custom Dataset class

# %%
class MyDataset(Dataset):
    def __init__(self, set, data1, data2, indices, labels, transform=None):

        assert data1.loc[indices,:].shape[0] == data2.loc[indices,:].shape[0] == len(labels), \
            "df1, df2, and labels must have the same number of samples (rows)"

        self.set = set
        self.data1 = data1.loc[indices,:]
        self.data2 = data2.loc[indices,:]
        self.indices = indices
        self.labels = labels
        self.transform = transform

    def __getitem__(self, idx):
        data1 = self.data1.iloc[idx].values
        data2 = self.data2.iloc[idx].values

        if self.transform:  
            data1, data2 = self.transform(data1, data2)

        #abundance_sum = data1 + data2
        #sorted_idx = abundance_sum.argsort()

        # Interleave
        interleaved_data = np.empty((len(data1) + len(data2)), dtype=np.float32)
        interleaved_data[0::2] = data1#[sorted_idx]
        interleaved_data[1::2] = data2#[sorted_idx]

        # Create RGB tensor
        sample = create_rgb_tensors(self.set, interleaved_data)
        label = torch.tensor(self.labels[idx], dtype=torch.long)

        return sample, label

    def __len__(self):
        return len(self.labels)

    def get_labels(self):
        return self.labels

# %% [markdown]
# ### Labels to integers

# %%
# Labels
localization_labels = LD.loc[:, 'Localization'].values
unique_labels = set(localization_labels)  # Get unique labels
label_to_int = {
    'Cytosol': 0,
    'Mitochondria': 1,
    'Nucleus': 2,
    'Secretory': 3
}
int_to_label = {v: k for k, v in label_to_int.items()}
int_to_label
# Out:
# {0: 'Cytosol', 1: 'Mitochondria', 2: 'Nucleus', 3: 'Secretory'}

# %% [markdown]
# ## Model training

# %% [markdown]
# ### Dataloaders

# %%
# Set seed to ensure reproducibility
set_seed(Seed)

# Split the data into training and validation sets using the labels indices, random state is set
train_indices, val_indices, train_labels, val_labels = train_test_split(LD.index, localization_labels, test_size=Validation_Fraction, random_state=42, stratify=localization_labels)

# Convert string labels to integers
train_labels = [label_to_int[label] for label in train_labels]
val_labels = [label_to_int[label] for label in val_labels]

# Define the transformation
transformation = AddNoise(set=Set, mean=0, std=StandardDeviation)

# Check Dataset argument to determine which dataset to use
if Set == 'Protein':
    train_dataset = MyDataset(Set, PD, PD, train_indices, train_labels, transform=transformation)
    val_dataset = MyDataset(Set, PD, PD, val_indices, val_labels, transform=None)
elif Set == 'mRNA':
    train_dataset = MyDataset(Set, MD, MD, train_indices, train_labels, transform=transformation)
    val_dataset = MyDataset(Set, MD, MD, val_indices, val_labels, transform=None)
elif Set == 'Protein + mRNA':
    train_dataset = MyDataset(Set, PD, MD, train_indices, train_labels, transform=transformation)
    val_dataset = MyDataset(Set, PD, MD, val_indices, val_labels, transform=None)
else:
    raise ValueError("Set must be 'Protein' or 'mRNA', or 'Protein + mRNA'")

# Create the dataloaders
train_loader = DataLoader(train_dataset, batch_size=Batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=Batch_size, shuffle=False)

# %% [markdown]
# ### Visualize the tensors in data loader

# %%
# Visualize the train data loader to see the transformed tensors
train_batch_images, train_batch_labels = next(iter(train_loader))

# Use first image in the batch
first_image_in_train_batch = train_batch_images[0]
first_label_in_train_batch = train_batch_labels[0]
first_image_in_train_batch
# Out:
# tensor([[[ 1.6146e+02,  1.6146e+02, -2.2923e+02, -2.2923e+02, -1.5035e+02,
#           -1.5035e+02, -1.0308e+02, -1.0308e+02, -1.2376e+02, -1.2376e+02,
#           -1.5903e+02, -1.5903e+02, -8.7335e+01, -8.7335e+01,  2.1392e+02,
#            2.1392e+02,  3.7661e+02,  3.7661e+02],
#          [ 2.4873e+02,  2.4873e+02,  3.3563e+01,  3.3563e+01,  1.1662e+02,
#            1.1662e+02, -1.3441e+02, -1.3441e+02,  4.0214e+02,  4.0214e+02,
#           -8.0217e+01, -8.0217e+01,  3.3853e+02,  3.3853e+02, -5.8140e+01,
#           -5.8140e+01, -8.6836e+01, -8.6836e+01],
#          [-7.1709e+01, -7.1709e+01,  3.3369e+02,  3.3369e+02, -2.9509e+02,
#           -2.9509e+02, -1.3935e+02, -1.3935e+02,  1.2872e+02,  1.2872e+02,
#           -2.5402e+02, -2.5402e+02, -8.3241e+01, -8.3241e+01,  2.5267e-01,
#            2.5267e-01, -3.7717e+02, -3.7717e+02],
#          [ 2.1605e+02,  2.1605e+02,  3.1575e+02,  3.1575e+02, -9.2673e+01,
#           -9.2673e+01, -2.4280e+02, -2.4280e+02, -4.5705e+01, -4.5705e+01,
#            1.1304e+02,  1.1304e+02,  3.6704e+01,  3.6704e+01,  2.8597e+02,
#            2.8597e+02,  6.7810e+01,  6.7810e+01],
#          [ 4.2921e+02,  4.2921e+02,  3.1060e+02,  3.1060e+02, -5.9303e+01,
#           -5.9303e+01, -2.4218e+02, -2.4218e+02,  2.7504e+02,  2.7504e+02,
#           -5.5539e+01, -5.5539e+01, -1.5276e+01, -1.5276e+01,  1.9510e+02,
#            1.9510e+02,  3.6495e+02,  3.6495e+02],
#          [-1.9224e+02, -1.9224e+02, -1.0828e+02, -1.0828e+02, -3.7214e+02,
#           -3.7214e+02,  1.4357e+01,  1.4357e+01,  3.5959e+01,  3.5959e+01,
#            9.7897e+01,  9.7897e+01,  3.9736e+02,  3.9736e+02,  2.5321e+02,
#            2.5321e+02, -9.2178e+01, -9.2178e+01],
#          [ 2.4918e+02,  2.4918e+02, -1.6138e+01, -1.6138e+01, -1.2112e+02,
#           -1.2112e+02,  1.6694e+02,  1.6694e+02,  2.4876e+02,  2.4876e+02,
#            2.8752e+02,  2.8752e+02, -2.5015e+02, -2.5015e+02,  1.4113e+02,
#            1.4113e+02, -6.4656e+02, -6.4656e+02],
#          [-1.9668e+01, -1.9668e+01,  3.7608e+02,  3.7608e+02,  4.3179e+02,
#            4.3179e+02, -1.3548e+02, -1.3548e+02, -2.0505e+02, -2.0505e+02,
#            2.9730e+02,  2.9730e+02,  3.0341e+02,  3.0341e+02,  1.0187e+02,
#            1.0187e+02, -9.8751e+01, -9.8751e+01],
#          [ 9.4936e+01,  9.4936e+01,  1.8993e+02,  1.8993e+02, -3.4051e+01,
#           -3.4051e+01, -1.9204e+02, -1.9204e+02,  3.1558e+02,  3.1558e+02,
#            1.6471e+02,  1.6471e+02, -7.4623e+01, -7.4623e+01, -2.3783e+02,
#           -2.3783e+02, -2.6676e+02, -2.6676e+02],
#          [-1.3749e+02, -1.3749e+02, -2.1106e+02, -2.1106e+02, -3.7810e+02,
#           -3.7810e+02, -1.8341e+01, -1.8341e+01,  7.9443e+01,  7.9443e+01,
#            1.0161e+02,  1.0161e+02,  8.4617e+01,  8.4617e+01,  6.3958e+01,
#            6.3958e+01,  4.0447e+01,  4.0447e+01],
#          [ 4.0341e+01,  4.0341e+01, -1.8792e+01, -1.8792e+01, -3.0573e+02,
#           -3.0573e+02,  2.2085e+00,  2.2085e+00, -4.0202e+00, -4.0202e+00,
#            1.0175e+01,  1.0175e+01, -3.2248e+02, -3.2248e+02, -2.0990e+02,
#           -2.0990e+02,  1.0746e+02,  1.0746e+02],
#          [ 1.8722e+02,  1.8722e+02,  6.2413e+01,  6.2413e+01, -7.5168e+01,
#           -7.5168e+01, -5.5350e+02, -5.5350e+02,  4.9806e+01,  4.9806e+01,
#           -1.7179e+02, -1.7179e+02,  1.4679e+02,  1.4679e+02, -1.8804e+02,
#           -1.8804e+02,  6.1478e+01,  6.1478e+01],
#          [ 1.4981e+02,  1.4981e+02, -4.4572e+02, -4.4572e+02, -3.8961e+02,
#           -3.8961e+02,  2.9527e+02,  2.9527e+02,  3.4981e+02,  3.4981e+02,
#            2.0980e+02,  2.0980e+02,  1.8903e+02,  1.8903e+02, -8.9386e+01,
#           -8.9386e+01, -1.4091e+02, -1.4091e+02],
#          [-2.8523e+02, -2.8523e+02, -1.1587e+01, -1.1587e+01, -2.8365e+02,
#           -2.8365e+02, -6.8796e+01, -6.8796e+01, -2.9265e+02, -2.9265e+02,
#            1.4936e+00,  1.4936e+00, -1.8456e+02, -1.8456e+02, -1.3986e+02,
#           -1.3986e+02,  4.2041e+02,  4.2041e+02],
#          [ 1.4426e+02,  1.4426e+02, -1.1670e+01, -1.1670e+01, -8.9021e+01,
#           -8.9021e+01,  2.3406e+02,  2.3406e+02, -9.1242e+02, -9.1242e+02,
#           -1.9944e+02, -1.9944e+02,  9.5819e+01,  9.5819e+01, -1.9215e+02,
#           -1.9215e+02, -2.9580e+02, -2.9580e+02],
#          [ 3.2666e+02,  3.2666e+02, -6.3277e+02, -6.3277e+02, -2.7789e+02,
#           -2.7789e+02,  5.5025e+02,  5.5025e+02, -1.7011e+02, -1.7011e+02,
#           -2.9838e+02, -2.9838e+02,  7.6235e+01,  7.6235e+01,  7.9593e+01,
#            7.9593e+01, -2.2934e+02, -2.2934e+02],
#          [ 2.1265e-01,  2.1265e-01,  3.5420e+02,  3.5420e+02, -1.1856e+02,
#           -1.1856e+02,  1.2938e+02,  1.2938e+02, -1.1654e+02, -1.1654e+02,
#            1.0807e+02,  1.0807e+02,  2.2483e+01,  2.2483e+01, -2.3651e+02,
#           -2.3651e+02, -1.6544e+02, -1.6544e+02],
#          [-5.3718e+01, -5.3718e+01,  5.4803e+02,  5.4803e+02,  5.1220e+02,
#            5.1220e+02,  1.5881e+02,  1.5881e+02, -3.6735e+02, -3.6735e+02,
#            1.0367e+02,  1.0367e+02, -1.2170e+02, -1.2170e+02,  1.3452e+02,
#            1.3452e+02,  2.7716e+02,  2.7716e+02]],
#
#         [[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00]],
#
#         [[ 9.3540e+01,  9.3540e+01,  4.8423e+02,  4.8423e+02,  4.0535e+02,
#            4.0535e+02,  3.5808e+02,  3.5808e+02,  3.7876e+02,  3.7876e+02,
#            4.1403e+02,  4.1403e+02,  3.4234e+02,  3.4234e+02,  4.1085e+01,
#            4.1085e+01, -1.2161e+02, -1.2161e+02],
#          [ 6.2746e+00,  6.2746e+00,  2.2144e+02,  2.2144e+02,  1.3838e+02,
#            1.3838e+02,  3.8941e+02,  3.8941e+02, -1.4714e+02, -1.4714e+02,
#            3.3522e+02,  3.3522e+02, -8.3530e+01, -8.3530e+01,  3.1314e+02,
#            3.1314e+02,  3.4184e+02,  3.4184e+02],
#          [ 3.2671e+02,  3.2671e+02, -7.8690e+01, -7.8690e+01,  5.5009e+02,
#            5.5009e+02,  3.9435e+02,  3.9435e+02,  1.2628e+02,  1.2628e+02,
#            5.0902e+02,  5.0902e+02,  3.3824e+02,  3.3824e+02,  2.5475e+02,
#            2.5475e+02,  6.3217e+02,  6.3217e+02],
#          [ 3.8945e+01,  3.8945e+01, -6.0750e+01, -6.0750e+01,  3.4767e+02,
#            3.4767e+02,  4.9780e+02,  4.9780e+02,  3.0071e+02,  3.0071e+02,
#            1.4196e+02,  1.4196e+02,  2.1830e+02,  2.1830e+02, -3.0968e+01,
#           -3.0968e+01,  1.8719e+02,  1.8719e+02],
#          [-1.7421e+02, -1.7421e+02, -5.5599e+01, -5.5599e+01,  3.1430e+02,
#            3.1430e+02,  4.9718e+02,  4.9718e+02, -2.0044e+01, -2.0044e+01,
#            3.1054e+02,  3.1054e+02,  2.7028e+02,  2.7028e+02,  5.9900e+01,
#            5.9900e+01, -1.0995e+02, -1.0995e+02],
#          [ 4.4724e+02,  4.4724e+02,  3.6328e+02,  3.6328e+02,  6.2714e+02,
#            6.2714e+02,  2.4064e+02,  2.4064e+02,  2.1904e+02,  2.1904e+02,
#            1.5710e+02,  1.5710e+02, -1.4236e+02, -1.4236e+02,  1.7947e+00,
#            1.7947e+00,  3.4718e+02,  3.4718e+02],
#          [ 5.8199e+00,  5.8199e+00,  2.7114e+02,  2.7114e+02,  3.7612e+02,
#            3.7612e+02,  8.8059e+01,  8.8059e+01,  6.2428e+00,  6.2428e+00,
#           -3.2519e+01, -3.2519e+01,  5.0515e+02,  5.0515e+02,  1.1387e+02,
#            1.1387e+02,  9.0156e+02,  9.0156e+02],
#          [ 2.7467e+02,  2.7467e+02, -1.2108e+02, -1.2108e+02, -1.7679e+02,
#           -1.7679e+02,  3.9048e+02,  3.9048e+02,  4.6005e+02,  4.6005e+02,
#           -4.2298e+01, -4.2298e+01, -4.8408e+01, -4.8408e+01,  1.5313e+02,
#            1.5313e+02,  3.5375e+02,  3.5375e+02],
#          [ 1.6006e+02,  1.6006e+02,  6.5073e+01,  6.5073e+01,  2.8905e+02,
#            2.8905e+02,  4.4704e+02,  4.4704e+02, -6.0575e+01, -6.0575e+01,
#            9.0285e+01,  9.0285e+01,  3.2962e+02,  3.2962e+02,  4.9283e+02,
#            4.9283e+02,  5.2176e+02,  5.2176e+02],
#          [ 3.9249e+02,  3.9249e+02,  4.6606e+02,  4.6606e+02,  6.3310e+02,
#            6.3310e+02,  2.7334e+02,  2.7334e+02,  1.7556e+02,  1.7556e+02,
#            1.5339e+02,  1.5339e+02,  1.7038e+02,  1.7038e+02,  1.9104e+02,
#            1.9104e+02,  2.1455e+02,  2.1455e+02],
#          [ 2.1466e+02,  2.1466e+02,  2.7379e+02,  2.7379e+02,  5.6073e+02,
#            5.6073e+02,  2.5279e+02,  2.5279e+02,  2.5902e+02,  2.5902e+02,
#            2.4482e+02,  2.4482e+02,  5.7748e+02,  5.7748e+02,  4.6490e+02,
#            4.6490e+02,  1.4754e+02,  1.4754e+02],
#          [ 6.7784e+01,  6.7784e+01,  1.9259e+02,  1.9259e+02,  3.3017e+02,
#            3.3017e+02,  8.0850e+02,  8.0850e+02,  2.0519e+02,  2.0519e+02,
#            4.2679e+02,  4.2679e+02,  1.0821e+02,  1.0821e+02,  4.4304e+02,
#            4.4304e+02,  1.9352e+02,  1.9352e+02],
#          [ 1.0519e+02,  1.0519e+02,  7.0072e+02,  7.0072e+02,  6.4461e+02,
#            6.4461e+02, -4.0273e+01, -4.0273e+01, -9.4813e+01, -9.4813e+01,
#            4.5204e+01,  4.5204e+01,  6.5968e+01,  6.5968e+01,  3.4439e+02,
#            3.4439e+02,  3.9591e+02,  3.9591e+02],
#          [ 5.4023e+02,  5.4023e+02,  2.6659e+02,  2.6659e+02,  5.3865e+02,
#            5.3865e+02,  3.2380e+02,  3.2380e+02,  5.4765e+02,  5.4765e+02,
#            2.5351e+02,  2.5351e+02,  4.3956e+02,  4.3956e+02,  3.9486e+02,
#            3.9486e+02, -1.6541e+02, -1.6541e+02],
#          [ 1.1074e+02,  1.1074e+02,  2.6667e+02,  2.6667e+02,  3.4402e+02,
#            3.4402e+02,  2.0943e+01,  2.0943e+01,  1.1674e+03,  1.1674e+03,
#            4.5444e+02,  4.5444e+02,  1.5918e+02,  1.5918e+02,  4.4715e+02,
#            4.4715e+02,  5.5080e+02,  5.5080e+02],
#          [-7.1664e+01, -7.1664e+01,  8.8777e+02,  8.8777e+02,  5.3289e+02,
#            5.3289e+02, -2.9525e+02, -2.9525e+02,  4.2511e+02,  4.2511e+02,
#            5.5338e+02,  5.5338e+02,  1.7877e+02,  1.7877e+02,  1.7541e+02,
#            1.7541e+02,  4.8434e+02,  4.8434e+02],
#          [ 2.5479e+02,  2.5479e+02, -9.9196e+01, -9.9196e+01,  3.7356e+02,
#            3.7356e+02,  1.2562e+02,  1.2562e+02,  3.7154e+02,  3.7154e+02,
#            1.4693e+02,  1.4693e+02,  2.3252e+02,  2.3252e+02,  4.9151e+02,
#            4.9151e+02,  4.2044e+02,  4.2044e+02],
#          [ 3.0872e+02,  3.0872e+02, -2.9303e+02, -2.9303e+02, -2.5720e+02,
#           -2.5720e+02,  9.6186e+01,  9.6186e+01,  6.2235e+02,  6.2235e+02,
#            1.5133e+02,  1.5133e+02,  3.7670e+02,  3.7670e+02,  1.2048e+02,
#            1.2048e+02, -2.2158e+01, -2.2158e+01]]])

# %%
# Visualize the train data loader to see the transformed tensors
val_batch_images, val_batch_labels = next(iter(val_loader))

# Use first image in the batch
first_image_in_val_batch = val_batch_images[0]
first_label_in_val_batch = val_batch_labels[0]
first_image_in_val_batch
# Out:
# tensor([[[ 3.4541e+02,  3.4541e+02,  4.7711e+02,  4.7711e+02,  6.7450e+02,
#            6.7450e+02,  3.5904e+02,  3.5904e+02,  5.5208e+02,  5.5208e+02,
#           -1.6531e+02, -1.6531e+02,  5.3996e+01,  5.3996e+01,  2.1900e+02,
#            2.1900e+02,  1.4293e+02,  1.4293e+02],
#          [ 2.7487e+00,  2.7487e+00, -2.8991e+02, -2.8991e+02, -1.8706e+02,
#           -1.8706e+02,  3.7346e+02,  3.7346e+02,  2.3789e+02,  2.3789e+02,
#            2.8675e+02,  2.8675e+02,  4.4306e+01,  4.4306e+01, -4.0288e+02,
#           -4.0288e+02, -4.5938e+01, -4.5938e+01],
#          [ 1.2233e+02,  1.2233e+02,  5.6446e+02,  5.6446e+02,  5.5002e+02,
#            5.5002e+02,  6.1671e+00,  6.1671e+00, -1.6898e+02, -1.6898e+02,
#            2.5458e+02,  2.5458e+02, -9.2732e+00, -9.2732e+00, -4.6378e+02,
#           -4.6378e+02,  7.2068e+01,  7.2068e+01],
#          [ 3.8112e+02,  3.8112e+02,  1.8983e+02,  1.8983e+02, -2.5876e+02,
#           -2.5876e+02,  1.1373e+02,  1.1373e+02,  3.7732e+01,  3.7732e+01,
#           -3.9792e+02, -3.9792e+02,  4.1467e+02,  4.1467e+02,  1.5659e+02,
#            1.5659e+02,  1.2122e+02,  1.2122e+02],
#          [ 4.9044e+01,  4.9044e+01,  1.8054e+01,  1.8054e+01, -1.1505e+02,
#           -1.1505e+02,  2.8234e+02,  2.8234e+02, -1.7246e+02, -1.7246e+02,
#            1.8230e+02,  1.8230e+02,  2.3350e+02,  2.3350e+02, -3.4482e+02,
#           -3.4482e+02, -3.7642e+02, -3.7642e+02],
#          [ 1.3516e+01,  1.3516e+01, -2.2393e+02, -2.2393e+02,  8.8769e+01,
#            8.8769e+01,  3.1639e+02,  3.1639e+02,  1.7736e+02,  1.7736e+02,
#            2.7951e+02,  2.7951e+02, -2.8921e+02, -2.8921e+02,  1.2210e+01,
#            1.2210e+01,  1.7772e+02,  1.7772e+02],
#          [-3.7060e+02, -3.7060e+02, -3.5489e+02, -3.5489e+02,  4.5851e+01,
#            4.5851e+01, -3.7995e+02, -3.7995e+02,  1.5984e+02,  1.5984e+02,
#           -8.5411e+01, -8.5411e+01,  2.3844e+01,  2.3844e+01, -1.0887e+02,
#           -1.0887e+02, -1.2452e+01, -1.2452e+01],
#          [-3.5314e+02, -3.5314e+02,  3.3757e+02,  3.3757e+02,  1.6630e+02,
#            1.6630e+02, -3.1627e+02, -3.1627e+02, -1.7502e+02, -1.7502e+02,
#           -2.2134e+02, -2.2134e+02,  2.7432e+02,  2.7432e+02, -2.0713e+02,
#           -2.0713e+02, -2.1222e+01, -2.1222e+01],
#          [-2.3089e+02, -2.3089e+02,  2.0811e+02,  2.0811e+02, -2.3024e+02,
#           -2.3024e+02,  1.7058e+01,  1.7058e+01, -1.2494e+01, -1.2494e+01,
#           -3.4267e+00, -3.4267e+00, -1.2634e+02, -1.2634e+02,  6.3352e+01,
#            6.3352e+01,  1.6314e+02,  1.6314e+02],
#          [-1.4218e+02, -1.4218e+02, -2.8185e+02, -2.8185e+02, -1.5642e+02,
#           -1.5642e+02,  3.8871e+01,  3.8871e+01,  2.0635e+02,  2.0635e+02,
#            2.9992e+02,  2.9992e+02, -5.9847e+01, -5.9847e+01, -2.6451e+02,
#           -2.6451e+02,  3.7590e+00,  3.7590e+00],
#          [ 1.0545e+01,  1.0545e+01, -4.7907e+01, -4.7907e+01, -9.4016e+01,
#           -9.4016e+01,  3.1233e+02,  3.1233e+02, -2.3942e+02, -2.3942e+02,
#           -3.1298e+02, -3.1298e+02,  2.9607e+00,  2.9607e+00,  2.8945e+02,
#            2.8945e+02,  5.1791e+01,  5.1791e+01],
#          [-1.1400e+02, -1.1400e+02,  2.8525e+02,  2.8525e+02, -2.1254e+02,
#           -2.1254e+02, -2.1797e+02, -2.1797e+02,  2.3411e+01,  2.3411e+01,
#            1.1226e+02,  1.1226e+02,  1.8827e+02,  1.8827e+02,  2.4721e+02,
#            2.4721e+02, -2.4724e+02, -2.4724e+02],
#          [ 7.6636e+01,  7.6636e+01, -3.7920e+02, -3.7920e+02, -2.4254e+02,
#           -2.4254e+02,  1.0882e+02,  1.0882e+02, -1.0058e+02, -1.0058e+02,
#            1.9954e+02,  1.9954e+02,  2.3611e+02,  2.3611e+02, -8.2831e+01,
#           -8.2831e+01,  2.5721e+02,  2.5721e+02],
#          [ 1.1526e+02,  1.1526e+02, -1.8732e+02, -1.8732e+02,  2.5828e+01,
#            2.5828e+01, -1.7338e+02, -1.7338e+02, -2.3196e+02, -2.3196e+02,
#           -3.6866e+01, -3.6866e+01,  3.3092e+02,  3.3092e+02, -2.0706e+02,
#           -2.0706e+02, -5.3299e+01, -5.3299e+01],
#          [-3.1510e+01, -3.1510e+01, -1.4844e+02, -1.4844e+02,  7.2244e+02,
#            7.2244e+02,  9.5309e+01,  9.5309e+01,  3.0011e+02,  3.0011e+02,
#            8.9788e+01,  8.9788e+01,  3.5179e+02,  3.5179e+02, -2.8148e+01,
#           -2.8148e+01, -3.0674e+02, -3.0674e+02],
#          [ 1.4995e+02,  1.4995e+02,  1.3546e+02,  1.3546e+02, -2.8478e+01,
#           -2.8478e+01,  5.8803e+01,  5.8803e+01, -1.1562e+02, -1.1562e+02,
#           -5.1024e+01, -5.1024e+01,  3.8669e+01,  3.8669e+01,  1.3957e+02,
#            1.3957e+02, -3.3113e+02, -3.3113e+02],
#          [-1.9963e+02, -1.9963e+02,  3.6083e+02,  3.6083e+02, -3.0195e+02,
#           -3.0195e+02, -1.2048e+02, -1.2048e+02,  8.8639e+01,  8.8639e+01,
#           -1.4119e+02, -1.4119e+02, -2.6578e+02, -2.6578e+02,  9.9384e+01,
#            9.9384e+01, -1.9508e+01, -1.9508e+01],
#          [-7.1874e+02, -7.1874e+02, -1.4713e+02, -1.4713e+02,  1.2759e+02,
#            1.2759e+02,  1.8152e+02,  1.8152e+02,  2.1735e+02,  2.1735e+02,
#            1.5495e+02,  1.5495e+02,  1.7227e+02,  1.7227e+02, -1.2717e+02,
#           -1.2717e+02,  3.3512e+02,  3.3512e+02]],
#
#         [[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00]],
#
#         [[-9.0406e+01, -9.0406e+01, -2.2211e+02, -2.2211e+02, -4.1950e+02,
#           -4.1950e+02, -1.0404e+02, -1.0404e+02, -2.9708e+02, -2.9708e+02,
#            4.2031e+02,  4.2031e+02,  2.0100e+02,  2.0100e+02,  3.6000e+01,
#            3.6000e+01,  1.1207e+02,  1.1207e+02],
#          [ 2.5225e+02,  2.5225e+02,  5.4491e+02,  5.4491e+02,  4.4206e+02,
#            4.4206e+02, -1.1846e+02, -1.1846e+02,  1.7105e+01,  1.7105e+01,
#           -3.1749e+01, -3.1749e+01,  2.1069e+02,  2.1069e+02,  6.5788e+02,
#            6.5788e+02,  3.0094e+02,  3.0094e+02],
#          [ 1.3267e+02,  1.3267e+02, -3.0946e+02, -3.0946e+02, -2.9502e+02,
#           -2.9502e+02,  2.4883e+02,  2.4883e+02,  4.2398e+02,  4.2398e+02,
#            4.2097e-01,  4.2097e-01,  2.6427e+02,  2.6427e+02,  7.1878e+02,
#            7.1878e+02,  1.8293e+02,  1.8293e+02],
#          [-1.2612e+02, -1.2612e+02,  6.5172e+01,  6.5172e+01,  5.1376e+02,
#            5.1376e+02,  1.4127e+02,  1.4127e+02,  2.1727e+02,  2.1727e+02,
#            6.5292e+02,  6.5292e+02, -1.5967e+02, -1.5967e+02,  9.8411e+01,
#            9.8411e+01,  1.3378e+02,  1.3378e+02],
#          [ 2.0596e+02,  2.0596e+02,  2.3695e+02,  2.3695e+02,  3.7005e+02,
#            3.7005e+02, -2.7337e+01, -2.7337e+01,  4.2746e+02,  4.2746e+02,
#            7.2703e+01,  7.2703e+01,  2.1504e+01,  2.1504e+01,  5.9982e+02,
#            5.9982e+02,  6.3142e+02,  6.3142e+02],
#          [ 2.4148e+02,  2.4148e+02,  4.7893e+02,  4.7893e+02,  1.6623e+02,
#            1.6623e+02, -6.1394e+01, -6.1394e+01,  7.7635e+01,  7.7635e+01,
#           -2.4508e+01, -2.4508e+01,  5.4421e+02,  5.4421e+02,  2.4279e+02,
#            2.4279e+02,  7.7283e+01,  7.7283e+01],
#          [ 6.2560e+02,  6.2560e+02,  6.0989e+02,  6.0989e+02,  2.0915e+02,
#            2.0915e+02,  6.3495e+02,  6.3495e+02,  9.5164e+01,  9.5164e+01,
#            3.4041e+02,  3.4041e+02,  2.3116e+02,  2.3116e+02,  3.6387e+02,
#            3.6387e+02,  2.6745e+02,  2.6745e+02],
#          [ 6.0814e+02,  6.0814e+02, -8.2568e+01, -8.2568e+01,  8.8695e+01,
#            8.8695e+01,  5.7127e+02,  5.7127e+02,  4.3002e+02,  4.3002e+02,
#            4.7634e+02,  4.7634e+02, -1.9319e+01, -1.9319e+01,  4.6213e+02,
#            4.6213e+02,  2.7622e+02,  2.7622e+02],
#          [ 4.8589e+02,  4.8589e+02,  4.6893e+01,  4.6893e+01,  4.8524e+02,
#            4.8524e+02,  2.3794e+02,  2.3794e+02,  2.6749e+02,  2.6749e+02,
#            2.5843e+02,  2.5843e+02,  3.8134e+02,  3.8134e+02,  1.9165e+02,
#            1.9165e+02,  9.1865e+01,  9.1865e+01],
#          [ 3.9718e+02,  3.9718e+02,  5.3685e+02,  5.3685e+02,  4.1142e+02,
#            4.1142e+02,  2.1613e+02,  2.1613e+02,  4.8652e+01,  4.8652e+01,
#           -4.4920e+01, -4.4920e+01,  3.1485e+02,  3.1485e+02,  5.1951e+02,
#            5.1951e+02,  2.5124e+02,  2.5124e+02],
#          [ 2.4445e+02,  2.4445e+02,  3.0291e+02,  3.0291e+02,  3.4902e+02,
#            3.4902e+02, -5.7325e+01, -5.7325e+01,  4.9442e+02,  4.9442e+02,
#            5.6798e+02,  5.6798e+02,  2.5204e+02,  2.5204e+02, -3.4454e+01,
#           -3.4454e+01,  2.0321e+02,  2.0321e+02],
#          [ 3.6900e+02,  3.6900e+02, -3.0246e+01, -3.0246e+01,  4.6754e+02,
#            4.6754e+02,  4.7297e+02,  4.7297e+02,  2.3159e+02,  2.3159e+02,
#            1.4274e+02,  1.4274e+02,  6.6732e+01,  6.6732e+01,  7.7908e+00,
#            7.7908e+00,  5.0224e+02,  5.0224e+02],
#          [ 1.7836e+02,  1.7836e+02,  6.3420e+02,  6.3420e+02,  4.9754e+02,
#            4.9754e+02,  1.4618e+02,  1.4618e+02,  3.5558e+02,  3.5558e+02,
#            5.5462e+01,  5.5462e+01,  1.8892e+01,  1.8892e+01,  3.3783e+02,
#            3.3783e+02, -2.2131e+00, -2.2131e+00],
#          [ 1.3974e+02,  1.3974e+02,  4.4232e+02,  4.4232e+02,  2.2917e+02,
#            2.2917e+02,  4.2838e+02,  4.2838e+02,  4.8696e+02,  4.8696e+02,
#            2.9187e+02,  2.9187e+02, -7.5923e+01, -7.5923e+01,  4.6206e+02,
#            4.6206e+02,  3.0830e+02,  3.0830e+02],
#          [ 2.8651e+02,  2.8651e+02,  4.0344e+02,  4.0344e+02, -4.6744e+02,
#           -4.6744e+02,  1.5969e+02,  1.5969e+02, -4.5106e+01, -4.5106e+01,
#            1.6521e+02,  1.6521e+02, -9.6792e+01, -9.6792e+01,  2.8315e+02,
#            2.8315e+02,  5.6174e+02,  5.6174e+02],
#          [ 1.0505e+02,  1.0505e+02,  1.1954e+02,  1.1954e+02,  2.8348e+02,
#            2.8348e+02,  1.9620e+02,  1.9620e+02,  3.7062e+02,  3.7062e+02,
#            3.0602e+02,  3.0602e+02,  2.1633e+02,  2.1633e+02,  1.1543e+02,
#            1.1543e+02,  5.8613e+02,  5.8613e+02],
#          [ 4.5463e+02,  4.5463e+02, -1.0583e+02, -1.0583e+02,  5.5695e+02,
#            5.5695e+02,  3.7548e+02,  3.7548e+02,  1.6636e+02,  1.6636e+02,
#            3.9619e+02,  3.9619e+02,  5.2078e+02,  5.2078e+02,  1.5562e+02,
#            1.5562e+02,  2.7451e+02,  2.7451e+02],
#          [ 9.7374e+02,  9.7374e+02,  4.0213e+02,  4.0213e+02,  1.2741e+02,
#            1.2741e+02,  7.3483e+01,  7.3483e+01,  3.7653e+01,  3.7653e+01,
#            1.0005e+02,  1.0005e+02,  8.2732e+01,  8.2732e+01,  3.8217e+02,
#            3.8217e+02, -8.0120e+01, -8.0120e+01]]])

# %%
# Count the validation labels
val_labels_count = pd.Series(val_dataset.get_labels()).value_counts()
print("Validation labels count:")
print(val_labels_count)
# Out:
# Validation labels count:
# 0    207
# 3    154
# 2    125
# 1     53
# Name: count, dtype: int64

# %% [markdown]
# ### Define model

# %%
class PixelPreservingNet(nn.Module):
    def __init__(self, in_channels=3):
        super(PixelPreservingNet, self).__init__()
        
        # Convolutional layers
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=in_channels, out_channels=16, kernel_size=3, padding=1), 
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.Dropout(0.3)  
        )  # Shape remains same after padding

        self.pool = nn.AvgPool2d(kernel_size=2, stride=2)  # Shape is reduced by half

        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Dropout(0.3)  
        )  # Shape remains same after padding

        self.conv3 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Dropout(0.3)  
        )  # Shape remains same after padding

        self.conv4 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Dropout(0.3)  
        )  # Shape remains same after padding

        self.conv5 = nn.Sequential(
            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Dropout(0.3)  
        )

        # Fully connected layers
        self.global_avg_pool = nn.AdaptiveAvgPool2d(1)  # Global Average Pooling layer
        self.fc1 = nn.Sequential(
            nn.Linear(256, 512), #256->512
            nn.ReLU(),
            nn.Dropout(0.4)
        )
        self.fc2 = nn.Sequential(
            nn.Linear(512, 256), #512->256
            nn.ReLU(),
            nn.Dropout(0.4)
        )

        # Output layer
        self.output = nn.Linear(256, 4) #256->4
    
    def forward(self, x):
        x = self.conv1(x)
        x = self.pool(x)
        x = self.conv2(x)
        x = self.pool(x)
        x = self.conv3(x)
        x = self.pool(x)
        x = self.conv4(x)
        x = self.pool(x)
        x = self.conv5(x)
        
        # Global Average Pooling
        x = self.global_avg_pool(x)
        x = torch.flatten(x, 1)
        
        x = self.fc1(x)
        x = self.fc2(x)
        x = self.output(x)
        return x

model = PixelPreservingNet(in_channels=3).to(device)

# %% [markdown]
# ### Define train loop

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    model.train()

    running_loss = 0.0
    correct_train = 0
    total_train = 0

    for X, y in dataloader:
        X = X.to(torch.float32).to(device)
        y = y.to(torch.long).to(device)

        optimizer.zero_grad()

        outputs = model(X)
        loss = loss_fn(outputs, y)

        # Confidence penalty
        softmax_probs = F.softmax(outputs, dim=1)
        entropy = -torch.sum(softmax_probs * torch.log(softmax_probs + 1e-10), dim=1)
        penalty = torch.mean(entropy)
        total_loss_with_penalty = loss - 0.1 * penalty

        total_loss_with_penalty.backward()
        optimizer.step()

        running_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        correct_train += (predicted == y).sum().item()
        total_train += y.size(0)

    avg_training_loss = running_loss / len(dataloader)
    training_accuracy = correct_train / total_train

    return avg_training_loss, training_accuracy

# %% [markdown]
# ### Define test loop

# %%
def test_loop(dataloader, model, loss_fn):
    
    model.eval()  # Set the model to evaluation mode

    test_loss = 0.0
    correct = 0
    total = 0

    y_pred = []
    y_true = []
    
    with torch.no_grad():  # Disable gradient calculation
        for X, y in dataloader:
            
            # Prepare data
            X = X.to(torch.float32).to(device)
            y = y.to(torch.long).to(device)

            # Forward pass: predict classes
            outputs = model(X)
            
            # Compute the loss
            test_loss += loss_fn(outputs, y).item()
            
            # Apply softmax and get prediction
            probs = F.softmax(outputs, dim=1)
            confidences, predicted = probs.max(dim=1)

            # Store predictions and true labels
            y_pred.extend(predicted.cpu().numpy())
            y_true.extend(y.cpu().numpy())

            # Count correct predictions
            correct += (predicted == y).sum().item() 

            # Count total predictions
            total += y.size(0) 

    # Calculate precision and recall for each class
    precision = precision_score(y_true, y_pred, average=None, zero_division=0.0)
    recall = recall_score(y_true, y_pred, average=None, zero_division=0.0)
    macro_f1 = f1_score(y_true, y_pred, average='macro')
    mcc = matthews_corrcoef(y_true, y_pred)

    # Per_class F1
    per_class_f1 = f1_score(y_true, y_pred, average=None, zero_division=0.0)

    # Global metrics
    avg_test_loss = test_loss / len(dataloader)
    test_accuracy = correct / total
        
    return avg_test_loss, test_accuracy, precision, recall, per_class_f1, macro_f1, mcc

# %% [markdown]
# ### Define focal loss

# %%
# Focal loss
class FocalLoss(nn.Module):
    def __init__(self, gamma=2.0, alpha=None, reduction='mean'):
        """
        :param gamma: focusing parameter (default=2.0)
        :param alpha: balance parameter, it can be a float or a tensor (default=None)
        :param reduction: specify the reduction to apply to the output: 'none' | 'mean' | 'sum' (default='mean')
        """
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.alpha = alpha
        self.reduction = reduction

    def forward(self, inputs, targets):
        # Compute cross-entropy loss
        BCE_loss = F.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-BCE_loss)  # pt is the probability of the true class
        
        # Compute the focal loss
        F_loss = (1 - pt) ** self.gamma * BCE_loss
        
        # Apply class weighting (alpha) if provided
        if self.alpha is not None:
            alpha = self.alpha[targets]
            F_loss = alpha * F_loss
        
        # Apply the specified reduction
        if self.reduction == 'mean':
            return F_loss.mean()
        elif self.reduction == 'sum':
            return F_loss.sum()
        else:
            return F_loss

# %% [markdown]
# ### Define early stopping

# %%
class EarlyStoppingWithCheckpoint:
    def __init__(self, patience=10, delta=0.0, save_path=None):
        self.patience = patience
        self.delta = delta
        self.save_path = save_path
        self.best_loss = None
        self.counter = 0
        self.early_stop = False

    def __call__(self, val_loss, model, save_path=None):
        # Allow override save_path if given in call
        if save_path is not None:
            self.save_path = save_path

        if self.best_loss is None:
            self.best_loss = val_loss
            if self.save_path is not None:
                self.save_checkpoint(model)
        elif val_loss > self.best_loss - self.delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_loss = val_loss
            if self.save_path is not None:
                self.save_checkpoint(model)
            self.counter = 0

    def save_checkpoint(self, model):
        torch.save(model.state_dict(), self.save_path)

# %% [markdown]
# ### Training and validation

# %% [markdown]
# Validation labels count:
# 0    207
# 3    154
# 2    125
# 1     53
# Name: count, dtype: int64

# %%
def compute_class_weights(class_counts): # inverse square root frequency for mild imbalance
    class_weights = 1.0 / torch.sqrt(torch.tensor(class_counts, dtype=torch.float))
    return class_weights / class_weights.sum()

# Given class counts
class_counts = [207, 53, 125, 154]
compute_class_weights(class_counts)
# Out:
# tensor([0.1844, 0.3645, 0.2373, 0.2138])

# %%
set_seed(Seed)

# Compute class weights
def compute_class_weights(class_counts): # inverse square root frequency for mild imbalance
    class_weights = 1.0 / torch.sqrt(torch.tensor(class_counts, dtype=torch.float))
    return class_weights / class_weights.sum()

# Given class counts
LossWeights = torch.tensor([0.180, 0.400, 0.185, 0.190], dtype=torch.float32) # manually set weights
LossWeights = LossWeights.to(device)

# Define the loss function, optimizer and scheduler
criterion = FocalLoss(alpha=LossWeights, gamma=2.0, reduction='mean')  # Focal loss for imbalanced classification
optimizer = optim.AdamW(model.parameters(), lr=Learner_rate, weight_decay=Weight_Decay)  # AdamW optimizer with weight decay

# Saved model path
model_path = os.path.join(model_folder_path, f"{Set}_NN3_unranked_model.pth")
best_macro_f1 = float('-inf')

# Set up performance dataframe to record loss, accuracy, precision and recall of each epoch
LossAccDF = pd.DataFrame(index=range(epochs),columns=['Epoch','TrainLoss','ValLoss','TrainAcc','ValAcc'])
PrecisionRecallDF = pd.DataFrame(columns=['Epoch','Class','Precision','Recall','Class F1','Macro F1','MCC'])

# Evaluate the model before training
avg_train_loss, train_accuracy, _, _, _, _, _ = test_loop(train_loader, model, criterion) # compute training performance
avg_val_loss, val_accuracy, precision, recall, per_class_f1, macro_f1, mcc = test_loop(val_loader, model, criterion) # compute validation performance

# Print initial performance
print(f"Before Training: "
      f"Training Loss: {avg_train_loss:.4f}, Training Accuracy: {train_accuracy:.4f}",
      f"Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}",
      f"Macro F1: {macro_f1:.4f}, Matthews Correlation Coefficient: {mcc:.4f}")

# Record the metric in the dataframe
LossAccDF.loc[0,:]=[0,avg_train_loss,avg_val_loss,train_accuracy,val_accuracy]
index=0
for i in range(4):
    PrecisionRecallDF.loc[index]=[0, i, precision[i], recall[i], per_class_f1[i], macro_f1, mcc]
    index += 1

# Training loop
for epoch in range(epochs):

    # Training phase
    avg_train_loss, train_accuracy = train_loop(train_loader, model, criterion, optimizer)
    
    # Validation phase
    avg_val_loss, val_accuracy, precision, recall, per_class_f1, macro_f1, mcc = test_loop(val_loader, model, criterion)
    
    # Print epoch loss and accuracy
    print(f"Epoch [{epoch+1}/{epochs}], "
          f"Training Loss: {avg_train_loss:.4f}, Training Accuracy: {train_accuracy:.4f}",
          f"Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}",
          f"Macro F1: {macro_f1:.4f}, Matthews Correlation Coefficient: {mcc:.4f}")   

    # Record the metric in the dataframe
    LossAccDF.loc[epoch+1,:]=[epoch+1,avg_train_loss,avg_val_loss,train_accuracy,val_accuracy]
    for i in range(4):
        PrecisionRecallDF.loc[index]=[epoch+1, i, precision[i], recall[i], per_class_f1[i], macro_f1, mcc]
        index += 1

    # Save best model based on macro F1
    if macro_f1 > best_macro_f1:
        best_macro_f1 = macro_f1
        torch.save(model.state_dict(), model_path)
        print(f"Best Macro F1 achieved: {best_macro_f1:.4f}")
        print(f"Saved new best model at epoch {epoch+1} with Macro F1: {macro_f1:.4f}")
# Out:
# Before Training: Training Loss: 0.1603, Training Accuracy: 0.2317 Validation Loss: 0.1602, Validation Accuracy: 0.2319 Macro F1: 0.0941, Matthews Correlation Coefficient: 0.0000
# Epoch [1/100], Training Loss: 0.1556, Training Accuracy: 0.3603 Validation Loss: 0.1564, Validation Accuracy: 0.4193 Macro F1: 0.2071, Matthews Correlation Coefficient: 0.1385
# Best Macro F1 achieved: 0.2071
# Saved new best model at epoch 1 with Macro F1: 0.2071
# Epoch [2/100], Training Loss: 0.1461, Training Accuracy: 0.4499 Validation Loss: 0.1402, Validation Accuracy: 0.5714 Macro F1: 0.4707, Matthews Correlation Coefficient: 0.3779
# Best Macro F1 achieved: 0.4707
# Saved new best model at epoch 2 with Macro F1: 0.4707
# Epoch [3/100], Training Loss: 0.1374, Training Accuracy: 0.5019 Validation Loss: 0.1319, Validation Accuracy: 0.5696 Macro F1: 0.5036, Matthews Correlation Coefficient: 0.4077
# Best Macro F1 achieved: 0.5036
# Saved new best model at epoch 3 with Macro F1: 0.5036
# Epoch [4/100], Training Loss: 0.1289, Training Accuracy: 0.5455 Validation Loss: 0.1246, Validation Accuracy: 0.5714 Macro F1: 0.5072, Matthews Correlation Coefficient: 0.4221
# Best Macro F1 achieved: 0.5072
# Saved new best model at epoch 4 with Macro F1: 0.5072
# Epoch [5/100], Training Loss: 0.1229, Training Accuracy: 0.5631 Validation Loss: 0.1176, Validation Accuracy: 0.5696 Macro F1: 0.5391, Matthews Correlation Coefficient: 0.4341
# Best Macro F1 achieved: 0.5391
# Saved new best model at epoch 5 with Macro F1: 0.5391
# Epoch [6/100], Training Loss: 0.1134, Training Accuracy: 0.5975 Validation Loss: 0.1094, Validation Accuracy: 0.6048 Macro F1: 0.5873, Matthews Correlation Coefficient: 0.4815
# Best Macro F1 achieved: 0.5873
# Saved new best model at epoch 6 with Macro F1: 0.5873
# Epoch [7/100], Training Loss: 0.1114, Training Accuracy: 0.6031 Validation Loss: 0.1036, Validation Accuracy: 0.6289 Macro F1: 0.6054, Matthews Correlation Coefficient: 0.5108
# Best Macro F1 achieved: 0.6054
# Saved new best model at epoch 7 with Macro F1: 0.6054
# Epoch [8/100], Training Loss: 0.1069, Training Accuracy: 0.6230 Validation Loss: 0.0980, Validation Accuracy: 0.6382 Macro F1: 0.6129, Matthews Correlation Coefficient: 0.5205
# Best Macro F1 achieved: 0.6129
# Saved new best model at epoch 8 with Macro F1: 0.6129
# Epoch [9/100], Training Loss: 0.1051, Training Accuracy: 0.6249 Validation Loss: 0.0961, Validation Accuracy: 0.6549 Macro F1: 0.6304, Matthews Correlation Coefficient: 0.5418
# Best Macro F1 achieved: 0.6304
# Saved new best model at epoch 9 with Macro F1: 0.6304
# Epoch [10/100], Training Loss: 0.1030, Training Accuracy: 0.6360 Validation Loss: 0.0970, Validation Accuracy: 0.6531 Macro F1: 0.6294, Matthews Correlation Coefficient: 0.5429
# Epoch [11/100], Training Loss: 0.0995, Training Accuracy: 0.6523 Validation Loss: 0.0922, Validation Accuracy: 0.6568 Macro F1: 0.6349, Matthews Correlation Coefficient: 0.5412
# Best Macro F1 achieved: 0.6349
# Saved new best model at epoch 11 with Macro F1: 0.6349
# Epoch [12/100], Training Loss: 0.0968, Training Accuracy: 0.6625 Validation Loss: 0.0912, Validation Accuracy: 0.6772 Macro F1: 0.6549, Matthews Correlation Coefficient: 0.5630
# Best Macro F1 achieved: 0.6549
# Saved new best model at epoch 12 with Macro F1: 0.6549
# Epoch [13/100], Training Loss: 0.0974, Training Accuracy: 0.6509 Validation Loss: 0.0895, Validation Accuracy: 0.6753 Macro F1: 0.6520, Matthews Correlation Coefficient: 0.5631
# Epoch [14/100], Training Loss: 0.0956, Training Accuracy: 0.6625 Validation Loss: 0.0886, Validation Accuracy: 0.6772 Macro F1: 0.6575, Matthews Correlation Coefficient: 0.5673
# Best Macro F1 achieved: 0.6575
# Saved new best model at epoch 14 with Macro F1: 0.6575
# Epoch [15/100], Training Loss: 0.0937, Training Accuracy: 0.6704 Validation Loss: 0.0854, Validation Accuracy: 0.6994 Macro F1: 0.6751, Matthews Correlation Coefficient: 0.5934
# Best Macro F1 achieved: 0.6751
# Saved new best model at epoch 15 with Macro F1: 0.6751
# Epoch [16/100], Training Loss: 0.0917, Training Accuracy: 0.6718 Validation Loss: 0.0879, Validation Accuracy: 0.6957 Macro F1: 0.6755, Matthews Correlation Coefficient: 0.5895
# Best Macro F1 achieved: 0.6755
# Saved new best model at epoch 16 with Macro F1: 0.6755
# Epoch [17/100], Training Loss: 0.0900, Training Accuracy: 0.6885 Validation Loss: 0.0865, Validation Accuracy: 0.6846 Macro F1: 0.6671, Matthews Correlation Coefficient: 0.5759
# Epoch [18/100], Training Loss: 0.0888, Training Accuracy: 0.6871 Validation Loss: 0.0830, Validation Accuracy: 0.7069 Macro F1: 0.6875, Matthews Correlation Coefficient: 0.5992
# Best Macro F1 achieved: 0.6875
# Saved new best model at epoch 18 with Macro F1: 0.6875
# Epoch [19/100], Training Loss: 0.0890, Training Accuracy: 0.6968 Validation Loss: 0.0835, Validation Accuracy: 0.7013 Macro F1: 0.6818, Matthews Correlation Coefficient: 0.5954
# Epoch [20/100], Training Loss: 0.0862, Training Accuracy: 0.7066 Validation Loss: 0.0811, Validation Accuracy: 0.7087 Macro F1: 0.6893, Matthews Correlation Coefficient: 0.6060
# Best Macro F1 achieved: 0.6893
# Saved new best model at epoch 20 with Macro F1: 0.6893
# Epoch [21/100], Training Loss: 0.0872, Training Accuracy: 0.6922 Validation Loss: 0.0806, Validation Accuracy: 0.7180 Macro F1: 0.6984, Matthews Correlation Coefficient: 0.6171
# Best Macro F1 achieved: 0.6984
# Saved new best model at epoch 21 with Macro F1: 0.6984
# Epoch [22/100], Training Loss: 0.0856, Training Accuracy: 0.6987 Validation Loss: 0.0801, Validation Accuracy: 0.7161 Macro F1: 0.6988, Matthews Correlation Coefficient: 0.6164
# Best Macro F1 achieved: 0.6988
# Saved new best model at epoch 22 with Macro F1: 0.6988
# Epoch [23/100], Training Loss: 0.0847, Training Accuracy: 0.6978 Validation Loss: 0.0811, Validation Accuracy: 0.7143 Macro F1: 0.6945, Matthews Correlation Coefficient: 0.6154
# Epoch [24/100], Training Loss: 0.0856, Training Accuracy: 0.6955 Validation Loss: 0.0788, Validation Accuracy: 0.7217 Macro F1: 0.7054, Matthews Correlation Coefficient: 0.6220
# Best Macro F1 achieved: 0.7054
# Saved new best model at epoch 24 with Macro F1: 0.7054
# Epoch [25/100], Training Loss: 0.0822, Training Accuracy: 0.7163 Validation Loss: 0.0768, Validation Accuracy: 0.7310 Macro F1: 0.7126, Matthews Correlation Coefficient: 0.6328
# Best Macro F1 achieved: 0.7126
# Saved new best model at epoch 25 with Macro F1: 0.7126
# Epoch [26/100], Training Loss: 0.0792, Training Accuracy: 0.7233 Validation Loss: 0.0777, Validation Accuracy: 0.7328 Macro F1: 0.7151, Matthews Correlation Coefficient: 0.6366
# Best Macro F1 achieved: 0.7151
# Saved new best model at epoch 26 with Macro F1: 0.7151
# Epoch [27/100], Training Loss: 0.0803, Training Accuracy: 0.7214 Validation Loss: 0.0775, Validation Accuracy: 0.7403 Macro F1: 0.7220, Matthews Correlation Coefficient: 0.6479
# Best Macro F1 achieved: 0.7220
# Saved new best model at epoch 27 with Macro F1: 0.7220
# Epoch [28/100], Training Loss: 0.0788, Training Accuracy: 0.7368 Validation Loss: 0.0746, Validation Accuracy: 0.7477 Macro F1: 0.7266, Matthews Correlation Coefficient: 0.6535
# Best Macro F1 achieved: 0.7266
# Saved new best model at epoch 28 with Macro F1: 0.7266
# Epoch [29/100], Training Loss: 0.0796, Training Accuracy: 0.7317 Validation Loss: 0.0760, Validation Accuracy: 0.7365 Macro F1: 0.7166, Matthews Correlation Coefficient: 0.6408
# Epoch [30/100], Training Loss: 0.0794, Training Accuracy: 0.7247 Validation Loss: 0.0767, Validation Accuracy: 0.7310 Macro F1: 0.7099, Matthews Correlation Coefficient: 0.6358
# Epoch [31/100], Training Loss: 0.0784, Training Accuracy: 0.7335 Validation Loss: 0.0733, Validation Accuracy: 0.7495 Macro F1: 0.7256, Matthews Correlation Coefficient: 0.6562
# Epoch [32/100], Training Loss: 0.0788, Training Accuracy: 0.7293 Validation Loss: 0.0744, Validation Accuracy: 0.7365 Macro F1: 0.7177, Matthews Correlation Coefficient: 0.6418
# Epoch [33/100], Training Loss: 0.0782, Training Accuracy: 0.7228 Validation Loss: 0.0722, Validation Accuracy: 0.7477 Macro F1: 0.7275, Matthews Correlation Coefficient: 0.6524
# Best Macro F1 achieved: 0.7275
# Saved new best model at epoch 33 with Macro F1: 0.7275
# Epoch [34/100], Training Loss: 0.0759, Training Accuracy: 0.7447 Validation Loss: 0.0734, Validation Accuracy: 0.7495 Macro F1: 0.7294, Matthews Correlation Coefficient: 0.6570
# Best Macro F1 achieved: 0.7294
# Saved new best model at epoch 34 with Macro F1: 0.7294
# Epoch [35/100], Training Loss: 0.0743, Training Accuracy: 0.7479 Validation Loss: 0.0726, Validation Accuracy: 0.7403 Macro F1: 0.7169, Matthews Correlation Coefficient: 0.6445
# Epoch [36/100], Training Loss: 0.0736, Training Accuracy: 0.7414 Validation Loss: 0.0723, Validation Accuracy: 0.7551 Macro F1: 0.7336, Matthews Correlation Coefficient: 0.6636
# Best Macro F1 achieved: 0.7336
# Saved new best model at epoch 36 with Macro F1: 0.7336
# Epoch [37/100], Training Loss: 0.0765, Training Accuracy: 0.7502 Validation Loss: 0.0722, Validation Accuracy: 0.7570 Macro F1: 0.7333, Matthews Correlation Coefficient: 0.6652
# Epoch [38/100], Training Loss: 0.0732, Training Accuracy: 0.7484 Validation Loss: 0.0720, Validation Accuracy: 0.7607 Macro F1: 0.7404, Matthews Correlation Coefficient: 0.6709
# Best Macro F1 achieved: 0.7404
# Saved new best model at epoch 38 with Macro F1: 0.7404
# Epoch [39/100], Training Loss: 0.0745, Training Accuracy: 0.7488 Validation Loss: 0.0711, Validation Accuracy: 0.7625 Macro F1: 0.7397, Matthews Correlation Coefficient: 0.6720
# Epoch [40/100], Training Loss: 0.0730, Training Accuracy: 0.7479 Validation Loss: 0.0703, Validation Accuracy: 0.7644 Macro F1: 0.7418, Matthews Correlation Coefficient: 0.6748
# Best Macro F1 achieved: 0.7418
# Saved new best model at epoch 40 with Macro F1: 0.7418
# Epoch [41/100], Training Loss: 0.0744, Training Accuracy: 0.7419 Validation Loss: 0.0724, Validation Accuracy: 0.7588 Macro F1: 0.7365, Matthews Correlation Coefficient: 0.6697
# Epoch [42/100], Training Loss: 0.0721, Training Accuracy: 0.7558 Validation Loss: 0.0714, Validation Accuracy: 0.7514 Macro F1: 0.7284, Matthews Correlation Coefficient: 0.6589
# Epoch [43/100], Training Loss: 0.0731, Training Accuracy: 0.7567 Validation Loss: 0.0702, Validation Accuracy: 0.7588 Macro F1: 0.7355, Matthews Correlation Coefficient: 0.6691
# Epoch [44/100], Training Loss: 0.0708, Training Accuracy: 0.7623 Validation Loss: 0.0700, Validation Accuracy: 0.7662 Macro F1: 0.7423, Matthews Correlation Coefficient: 0.6773
# Best Macro F1 achieved: 0.7423
# Saved new best model at epoch 44 with Macro F1: 0.7423
# Epoch [45/100], Training Loss: 0.0695, Training Accuracy: 0.7628 Validation Loss: 0.0679, Validation Accuracy: 0.7662 Macro F1: 0.7419, Matthews Correlation Coefficient: 0.6770
# Epoch [46/100], Training Loss: 0.0699, Training Accuracy: 0.7651 Validation Loss: 0.0687, Validation Accuracy: 0.7607 Macro F1: 0.7345, Matthews Correlation Coefficient: 0.6697
# Epoch [47/100], Training Loss: 0.0686, Training Accuracy: 0.7721 Validation Loss: 0.0691, Validation Accuracy: 0.7607 Macro F1: 0.7366, Matthews Correlation Coefficient: 0.6706
# Epoch [48/100], Training Loss: 0.0700, Training Accuracy: 0.7679 Validation Loss: 0.0692, Validation Accuracy: 0.7588 Macro F1: 0.7333, Matthews Correlation Coefficient: 0.6682
# Epoch [49/100], Training Loss: 0.0682, Training Accuracy: 0.7860 Validation Loss: 0.0688, Validation Accuracy: 0.7607 Macro F1: 0.7372, Matthews Correlation Coefficient: 0.6705
# Epoch [50/100], Training Loss: 0.0697, Training Accuracy: 0.7721 Validation Loss: 0.0680, Validation Accuracy: 0.7811 Macro F1: 0.7585, Matthews Correlation Coefficient: 0.6960
# Best Macro F1 achieved: 0.7585
# Saved new best model at epoch 50 with Macro F1: 0.7585
# Epoch [51/100], Training Loss: 0.0680, Training Accuracy: 0.7786 Validation Loss: 0.0676, Validation Accuracy: 0.7737 Macro F1: 0.7537, Matthews Correlation Coefficient: 0.6863
# Epoch [52/100], Training Loss: 0.0673, Training Accuracy: 0.7781 Validation Loss: 0.0682, Validation Accuracy: 0.7699 Macro F1: 0.7455, Matthews Correlation Coefficient: 0.6814
# Epoch [53/100], Training Loss: 0.0677, Training Accuracy: 0.7869 Validation Loss: 0.0675, Validation Accuracy: 0.7755 Macro F1: 0.7516, Matthews Correlation Coefficient: 0.6891
# Epoch [54/100], Training Loss: 0.0682, Training Accuracy: 0.7711 Validation Loss: 0.0691, Validation Accuracy: 0.7718 Macro F1: 0.7501, Matthews Correlation Coefficient: 0.6830
# Epoch [55/100], Training Loss: 0.0679, Training Accuracy: 0.7707 Validation Loss: 0.0692, Validation Accuracy: 0.7681 Macro F1: 0.7476, Matthews Correlation Coefficient: 0.6799
# Epoch [56/100], Training Loss: 0.0668, Training Accuracy: 0.7804 Validation Loss: 0.0674, Validation Accuracy: 0.7792 Macro F1: 0.7518, Matthews Correlation Coefficient: 0.6932
# Epoch [57/100], Training Loss: 0.0679, Training Accuracy: 0.7721 Validation Loss: 0.0676, Validation Accuracy: 0.7996 Macro F1: 0.7758, Matthews Correlation Coefficient: 0.7181
# Best Macro F1 achieved: 0.7758
# Saved new best model at epoch 57 with Macro F1: 0.7758
# Epoch [58/100], Training Loss: 0.0661, Training Accuracy: 0.7841 Validation Loss: 0.0670, Validation Accuracy: 0.7866 Macro F1: 0.7596, Matthews Correlation Coefficient: 0.7017
# Epoch [59/100], Training Loss: 0.0651, Training Accuracy: 0.7911 Validation Loss: 0.0658, Validation Accuracy: 0.7922 Macro F1: 0.7659, Matthews Correlation Coefficient: 0.7102
# Epoch [60/100], Training Loss: 0.0664, Training Accuracy: 0.7906 Validation Loss: 0.0662, Validation Accuracy: 0.7941 Macro F1: 0.7678, Matthews Correlation Coefficient: 0.7124
# Epoch [61/100], Training Loss: 0.0645, Training Accuracy: 0.7934 Validation Loss: 0.0665, Validation Accuracy: 0.7941 Macro F1: 0.7703, Matthews Correlation Coefficient: 0.7121
# Epoch [62/100], Training Loss: 0.0652, Training Accuracy: 0.7888 Validation Loss: 0.0666, Validation Accuracy: 0.7978 Macro F1: 0.7709, Matthews Correlation Coefficient: 0.7176
# Epoch [63/100], Training Loss: 0.0651, Training Accuracy: 0.7786 Validation Loss: 0.0673, Validation Accuracy: 0.7941 Macro F1: 0.7767, Matthews Correlation Coefficient: 0.7116
# Best Macro F1 achieved: 0.7767
# Saved new best model at epoch 63 with Macro F1: 0.7767
# Epoch [64/100], Training Loss: 0.0636, Training Accuracy: 0.7957 Validation Loss: 0.0654, Validation Accuracy: 0.8015 Macro F1: 0.7793, Matthews Correlation Coefficient: 0.7223
# Best Macro F1 achieved: 0.7793
# Saved new best model at epoch 64 with Macro F1: 0.7793
# Epoch [65/100], Training Loss: 0.0632, Training Accuracy: 0.7897 Validation Loss: 0.0652, Validation Accuracy: 0.7978 Macro F1: 0.7729, Matthews Correlation Coefficient: 0.7171
# Epoch [66/100], Training Loss: 0.0638, Training Accuracy: 0.7855 Validation Loss: 0.0670, Validation Accuracy: 0.7941 Macro F1: 0.7701, Matthews Correlation Coefficient: 0.7122
# Epoch [67/100], Training Loss: 0.0625, Training Accuracy: 0.7878 Validation Loss: 0.0663, Validation Accuracy: 0.7959 Macro F1: 0.7724, Matthews Correlation Coefficient: 0.7147
# Epoch [68/100], Training Loss: 0.0630, Training Accuracy: 0.7999 Validation Loss: 0.0643, Validation Accuracy: 0.8033 Macro F1: 0.7810, Matthews Correlation Coefficient: 0.7246
# Best Macro F1 achieved: 0.7810
# Saved new best model at epoch 68 with Macro F1: 0.7810
# Epoch [69/100], Training Loss: 0.0617, Training Accuracy: 0.7920 Validation Loss: 0.0659, Validation Accuracy: 0.8015 Macro F1: 0.7794, Matthews Correlation Coefficient: 0.7226
# Epoch [70/100], Training Loss: 0.0624, Training Accuracy: 0.7962 Validation Loss: 0.0654, Validation Accuracy: 0.8071 Macro F1: 0.7838, Matthews Correlation Coefficient: 0.7285
# Best Macro F1 achieved: 0.7838
# Saved new best model at epoch 70 with Macro F1: 0.7838
# Epoch [71/100], Training Loss: 0.0632, Training Accuracy: 0.7888 Validation Loss: 0.0657, Validation Accuracy: 0.7904 Macro F1: 0.7620, Matthews Correlation Coefficient: 0.7090
# Epoch [72/100], Training Loss: 0.0634, Training Accuracy: 0.7916 Validation Loss: 0.0665, Validation Accuracy: 0.7922 Macro F1: 0.7693, Matthews Correlation Coefficient: 0.7101
# Epoch [73/100], Training Loss: 0.0605, Training Accuracy: 0.8087 Validation Loss: 0.0648, Validation Accuracy: 0.7941 Macro F1: 0.7638, Matthews Correlation Coefficient: 0.7133
# Epoch [74/100], Training Loss: 0.0621, Training Accuracy: 0.8022 Validation Loss: 0.0655, Validation Accuracy: 0.7996 Macro F1: 0.7724, Matthews Correlation Coefficient: 0.7201
# Epoch [75/100], Training Loss: 0.0611, Training Accuracy: 0.8018 Validation Loss: 0.0648, Validation Accuracy: 0.8108 Macro F1: 0.7889, Matthews Correlation Coefficient: 0.7346
# Best Macro F1 achieved: 0.7889
# Saved new best model at epoch 75 with Macro F1: 0.7889
# Epoch [76/100], Training Loss: 0.0590, Training Accuracy: 0.8083 Validation Loss: 0.0665, Validation Accuracy: 0.7959 Macro F1: 0.7737, Matthews Correlation Coefficient: 0.7124
# Epoch [77/100], Training Loss: 0.0613, Training Accuracy: 0.8045 Validation Loss: 0.0654, Validation Accuracy: 0.8015 Macro F1: 0.7773, Matthews Correlation Coefficient: 0.7219
# Epoch [78/100], Training Loss: 0.0615, Training Accuracy: 0.7981 Validation Loss: 0.0667, Validation Accuracy: 0.7885 Macro F1: 0.7624, Matthews Correlation Coefficient: 0.7069
# Epoch [79/100], Training Loss: 0.0577, Training Accuracy: 0.8175 Validation Loss: 0.0643, Validation Accuracy: 0.7996 Macro F1: 0.7772, Matthews Correlation Coefficient: 0.7196
# Epoch [80/100], Training Loss: 0.0601, Training Accuracy: 0.8036 Validation Loss: 0.0661, Validation Accuracy: 0.8033 Macro F1: 0.7860, Matthews Correlation Coefficient: 0.7235
# Epoch [81/100], Training Loss: 0.0594, Training Accuracy: 0.8004 Validation Loss: 0.0651, Validation Accuracy: 0.8033 Macro F1: 0.7766, Matthews Correlation Coefficient: 0.7249
# Epoch [82/100], Training Loss: 0.0575, Training Accuracy: 0.8092 Validation Loss: 0.0644, Validation Accuracy: 0.8015 Macro F1: 0.7769, Matthews Correlation Coefficient: 0.7203
# Epoch [83/100], Training Loss: 0.0602, Training Accuracy: 0.8087 Validation Loss: 0.0658, Validation Accuracy: 0.7922 Macro F1: 0.7712, Matthews Correlation Coefficient: 0.7081
# Epoch [84/100], Training Loss: 0.0601, Training Accuracy: 0.8194 Validation Loss: 0.0668, Validation Accuracy: 0.7885 Macro F1: 0.7612, Matthews Correlation Coefficient: 0.7051
# Epoch [85/100], Training Loss: 0.0575, Training Accuracy: 0.8203 Validation Loss: 0.0657, Validation Accuracy: 0.7922 Macro F1: 0.7662, Matthews Correlation Coefficient: 0.7094
# Epoch [86/100], Training Loss: 0.0570, Training Accuracy: 0.8231 Validation Loss: 0.0668, Validation Accuracy: 0.7922 Macro F1: 0.7669, Matthews Correlation Coefficient: 0.7113
# Epoch [87/100], Training Loss: 0.0574, Training Accuracy: 0.8138 Validation Loss: 0.0649, Validation Accuracy: 0.7996 Macro F1: 0.7743, Matthews Correlation Coefficient: 0.7182
# Epoch [88/100], Training Loss: 0.0587, Training Accuracy: 0.8171 Validation Loss: 0.0649, Validation Accuracy: 0.8163 Macro F1: 0.7952, Matthews Correlation Coefficient: 0.7415
# Best Macro F1 achieved: 0.7952
# Saved new best model at epoch 88 with Macro F1: 0.7952
# Epoch [89/100], Training Loss: 0.0571, Training Accuracy: 0.8189 Validation Loss: 0.0644, Validation Accuracy: 0.8145 Macro F1: 0.7923, Matthews Correlation Coefficient: 0.7393
# Epoch [90/100], Training Loss: 0.0587, Training Accuracy: 0.8180 Validation Loss: 0.0649, Validation Accuracy: 0.8015 Macro F1: 0.7777, Matthews Correlation Coefficient: 0.7218
# Epoch [91/100], Training Loss: 0.0562, Training Accuracy: 0.8273 Validation Loss: 0.0644, Validation Accuracy: 0.8015 Macro F1: 0.7789, Matthews Correlation Coefficient: 0.7221
# Epoch [92/100], Training Loss: 0.0557, Training Accuracy: 0.8171 Validation Loss: 0.0661, Validation Accuracy: 0.7996 Macro F1: 0.7712, Matthews Correlation Coefficient: 0.7183
# Epoch [93/100], Training Loss: 0.0578, Training Accuracy: 0.8110 Validation Loss: 0.0656, Validation Accuracy: 0.8033 Macro F1: 0.7779, Matthews Correlation Coefficient: 0.7239
# Epoch [94/100], Training Loss: 0.0572, Training Accuracy: 0.8110 Validation Loss: 0.0656, Validation Accuracy: 0.8033 Macro F1: 0.7744, Matthews Correlation Coefficient: 0.7240
# Epoch [95/100], Training Loss: 0.0580, Training Accuracy: 0.8227 Validation Loss: 0.0645, Validation Accuracy: 0.8089 Macro F1: 0.7850, Matthews Correlation Coefficient: 0.7319
# Epoch [96/100], Training Loss: 0.0558, Training Accuracy: 0.8222 Validation Loss: 0.0644, Validation Accuracy: 0.8108 Macro F1: 0.7826, Matthews Correlation Coefficient: 0.7351
# Epoch [97/100], Training Loss: 0.0571, Training Accuracy: 0.8189 Validation Loss: 0.0658, Validation Accuracy: 0.8015 Macro F1: 0.7741, Matthews Correlation Coefficient: 0.7212
# Epoch [98/100], Training Loss: 0.0565, Training Accuracy: 0.8259 Validation Loss: 0.0661, Validation Accuracy: 0.8015 Macro F1: 0.7751, Matthews Correlation Coefficient: 0.7217
# Epoch [99/100], Training Loss: 0.0580, Training Accuracy: 0.8231 Validation Loss: 0.0653, Validation Accuracy: 0.8071 Macro F1: 0.7817, Matthews Correlation Coefficient: 0.7288
# Epoch [100/100], Training Loss: 0.0570, Training Accuracy: 0.8166 Validation Loss: 0.0645, Validation Accuracy: 0.8108 Macro F1: 0.7846, Matthews Correlation Coefficient: 0.7340

# %% [markdown]
# ### 5-fold cross validation

# %%
cv_summary = []

for run in range(1):
    print(f"\n========== Run {run+1} ==========")

    set_seed(Seed + run)
    kfold = KFold(n_splits=5, shuffle=True, random_state=Seed + run)

    full_labels = [label_to_int[label] for label in LD['Localization'].values]

    if Set == 'Protein':
        train_dataset = MyDataset(Set, PD, PD, LD.index, full_labels, transform=transformation)
        val_dataset = MyDataset(Set, PD, PD, LD.index, full_labels, transform=None)
    elif Set == 'mRNA':
        train_dataset = MyDataset(Set, MD, MD, LD.index, full_labels, transform=transformation)
        val_dataset = MyDataset(Set, MD, MD, LD.index, full_labels, transform=None)
    elif Set == 'Protein + mRNA':
        train_dataset = MyDataset(Set, PD, MD, LD.index, full_labels, transform=transformation)
        val_dataset = MyDataset(Set, PD, MD, LD.index, full_labels, transform=None)
    else:
        raise ValueError("Invalid dataset selection. Choose 'Protein', 'mRNA', 'Protein + mRNA'.")

    fold_metrics = []

    for fold, (train_ids, val_ids) in enumerate(kfold.split(train_dataset)):
        print(f"\n--- Fold {fold+1}/5 ---")

        train_loader = DataLoader(torch.utils.data.Subset(train_dataset, train_ids), batch_size=Batch_size, shuffle=True)
        val_loader = DataLoader(torch.utils.data.Subset(val_dataset, val_ids), batch_size=Batch_size, shuffle=False)

        model = PixelPreservingNet(in_channels=3).to(device)
        optimizer = optim.AdamW(model.parameters(), lr=Learner_rate, weight_decay=Weight_Decay)
        criterion = FocalLoss(alpha=LossWeights, gamma=2.0, reduction='mean')

        best_macro_f1 = -float('inf')
        best_epoch = 0
        best_model_wts = copy.deepcopy(model.state_dict())

        for epoch in range(epochs):
            train_loss, train_acc = train_loop(train_loader, model, criterion, optimizer)
            val_loss, val_acc, prec, rec, f1s, macro_f1, _ = test_loop(val_loader, model, criterion)
            #scheduler.step(val_loss)

            if macro_f1 > best_macro_f1:
                best_macro_f1 = macro_f1
                best_epoch = epoch
                best_model_wts = copy.deepcopy(model.state_dict())
                print(f"Saved new best model at epoch {epoch+1} with Macro F1: {macro_f1:.4f}")


        # Load and evaluate again (ensures consistency)
        model.load_state_dict(best_model_wts)
        _, _, prec, rec, f1s, macro_f1, mcc = test_loop(val_loader, model, criterion)

        fold_metrics.append({
            "Precision_C0": prec[0], "Precision_C1": prec[1], "Precision_C2": prec[2], "Precision_C3": prec[3],
            "Recall_C0": rec[0], "Recall_C1": rec[1], "Recall_C2": rec[2], "Recall_C3": rec[3],
            "F1_C0": f1s[0], "F1_C1": f1s[1], "F1_C2": f1s[2], "F1_C3": f1s[3],
            "Macro_F1": macro_f1,
            "MCC": mcc,
        })

    df_folds = pd.DataFrame(fold_metrics)
    #avg_metrics = df_folds.mean(numeric_only=True)
    #avg_metrics["Run"] = run + 1
    #cv_summary.append(avg_metrics)

# Save run-level summary
cv_summary_df = pd.DataFrame(df_folds)
cv_summary_df.to_csv(cv_folder_path + f'{Set}_unranked_5FoldCV_PerClassOnly.csv', index=False)
# Out:
# ========== Run 1 ==========
#
# --- Fold 1/5 ---
# Saved new best model at epoch 1 with Macro F1: 0.1660
# Saved new best model at epoch 2 with Macro F1: 0.4370
# Saved new best model at epoch 3 with Macro F1: 0.4703
# Saved new best model at epoch 4 with Macro F1: 0.4899
# Saved new best model at epoch 5 with Macro F1: 0.5613
# Saved new best model at epoch 6 with Macro F1: 0.6064
# Saved new best model at epoch 7 with Macro F1: 0.6338
# Saved new best model at epoch 8 with Macro F1: 0.6521
# Saved new best model at epoch 10 with Macro F1: 0.6617
# Saved new best model at epoch 11 with Macro F1: 0.6740
# Saved new best model at epoch 12 with Macro F1: 0.6821
# Saved new best model at epoch 15 with Macro F1: 0.6884
# Saved new best model at epoch 16 with Macro F1: 0.6911
# Saved new best model at epoch 17 with Macro F1: 0.6978
# Saved new best model at epoch 20 with Macro F1: 0.6998
# Saved new best model at epoch 22 with Macro F1: 0.7105
# Saved new best model at epoch 24 with Macro F1: 0.7117
# Saved new best model at epoch 25 with Macro F1: 0.7138
# Saved new best model at epoch 26 with Macro F1: 0.7155
# Saved new best model at epoch 27 with Macro F1: 0.7212
# Saved new best model at epoch 30 with Macro F1: 0.7229
# Saved new best model at epoch 31 with Macro F1: 0.7360
# Saved new best model at epoch 34 with Macro F1: 0.7422
# Saved new best model at epoch 39 with Macro F1: 0.7448
# Saved new best model at epoch 41 with Macro F1: 0.7518
# Saved new best model at epoch 44 with Macro F1: 0.7596
# Saved new best model at epoch 47 with Macro F1: 0.7603
# Saved new best model at epoch 56 with Macro F1: 0.7652
# Saved new best model at epoch 58 with Macro F1: 0.7665
# Saved new best model at epoch 61 with Macro F1: 0.7785
# Saved new best model at epoch 67 with Macro F1: 0.7790
# Saved new best model at epoch 71 with Macro F1: 0.7873
# Saved new best model at epoch 82 with Macro F1: 0.7995
#
# --- Fold 2/5 ---
# Saved new best model at epoch 1 with Macro F1: 0.1733
# Saved new best model at epoch 2 with Macro F1: 0.4598
# Saved new best model at epoch 3 with Macro F1: 0.4826
# Saved new best model at epoch 4 with Macro F1: 0.5368
# Saved new best model at epoch 5 with Macro F1: 0.5801
# Saved new best model at epoch 6 with Macro F1: 0.5887
# Saved new best model at epoch 7 with Macro F1: 0.6155
# Saved new best model at epoch 8 with Macro F1: 0.6188
# Saved new best model at epoch 9 with Macro F1: 0.6417
# Saved new best model at epoch 10 with Macro F1: 0.6574
# Saved new best model at epoch 11 with Macro F1: 0.6621
# Saved new best model at epoch 12 with Macro F1: 0.6657
# Saved new best model at epoch 13 with Macro F1: 0.6727
# Saved new best model at epoch 14 with Macro F1: 0.6866
# Saved new best model at epoch 16 with Macro F1: 0.6883
# Saved new best model at epoch 18 with Macro F1: 0.6898
# Saved new best model at epoch 21 with Macro F1: 0.6906
# Saved new best model at epoch 22 with Macro F1: 0.7009
# Saved new best model at epoch 23 with Macro F1: 0.7089
# Saved new best model at epoch 27 with Macro F1: 0.7217
# Saved new best model at epoch 29 with Macro F1: 0.7300
# Saved new best model at epoch 33 with Macro F1: 0.7380
# Saved new best model at epoch 43 with Macro F1: 0.7514
# Saved new best model at epoch 49 with Macro F1: 0.7557
# Saved new best model at epoch 55 with Macro F1: 0.7604
# Saved new best model at epoch 61 with Macro F1: 0.7655
# Saved new best model at epoch 78 with Macro F1: 0.7660
# Saved new best model at epoch 82 with Macro F1: 0.7689
# Saved new best model at epoch 88 with Macro F1: 0.7761
# Saved new best model at epoch 89 with Macro F1: 0.7894
#
# --- Fold 3/5 ---
# Saved new best model at epoch 1 with Macro F1: 0.1676
# Saved new best model at epoch 2 with Macro F1: 0.3053
# Saved new best model at epoch 3 with Macro F1: 0.5004
# Saved new best model at epoch 4 with Macro F1: 0.5259
# Saved new best model at epoch 5 with Macro F1: 0.5830
# Saved new best model at epoch 6 with Macro F1: 0.6214
# Saved new best model at epoch 7 with Macro F1: 0.6511
# Saved new best model at epoch 10 with Macro F1: 0.6707
# Saved new best model at epoch 11 with Macro F1: 0.6736
# Saved new best model at epoch 13 with Macro F1: 0.6809
# Saved new best model at epoch 14 with Macro F1: 0.6930
# Saved new best model at epoch 15 with Macro F1: 0.6949
# Saved new best model at epoch 16 with Macro F1: 0.6980
# Saved new best model at epoch 17 with Macro F1: 0.7071
# Saved new best model at epoch 18 with Macro F1: 0.7142
# Saved new best model at epoch 20 with Macro F1: 0.7171
# Saved new best model at epoch 21 with Macro F1: 0.7294
# Saved new best model at epoch 24 with Macro F1: 0.7306
# Saved new best model at epoch 25 with Macro F1: 0.7338
# Saved new best model at epoch 26 with Macro F1: 0.7502
# Saved new best model at epoch 31 with Macro F1: 0.7570
# Saved new best model at epoch 33 with Macro F1: 0.7580
# Saved new best model at epoch 37 with Macro F1: 0.7581
# Saved new best model at epoch 38 with Macro F1: 0.7605
# Saved new best model at epoch 39 with Macro F1: 0.7621
# Saved new best model at epoch 40 with Macro F1: 0.7637
# Saved new best model at epoch 42 with Macro F1: 0.7732
# Saved new best model at epoch 45 with Macro F1: 0.7783
# Saved new best model at epoch 46 with Macro F1: 0.7829
# Saved new best model at epoch 62 with Macro F1: 0.7835
# Saved new best model at epoch 66 with Macro F1: 0.7841
# Saved new best model at epoch 78 with Macro F1: 0.7895
# Saved new best model at epoch 79 with Macro F1: 0.7906
# Saved new best model at epoch 80 with Macro F1: 0.7994
# Saved new best model at epoch 81 with Macro F1: 0.8024
# Saved new best model at epoch 83 with Macro F1: 0.8061
# Saved new best model at epoch 89 with Macro F1: 0.8066
# Saved new best model at epoch 93 with Macro F1: 0.8117
# Saved new best model at epoch 94 with Macro F1: 0.8124
#
# --- Fold 4/5 ---
# Saved new best model at epoch 1 with Macro F1: 0.2246
# Saved new best model at epoch 2 with Macro F1: 0.3553
# Saved new best model at epoch 3 with Macro F1: 0.4888
# Saved new best model at epoch 4 with Macro F1: 0.5581
# Saved new best model at epoch 5 with Macro F1: 0.5844
# Saved new best model at epoch 6 with Macro F1: 0.6017
# Saved new best model at epoch 7 with Macro F1: 0.6039
# Saved new best model at epoch 8 with Macro F1: 0.6263
# Saved new best model at epoch 9 with Macro F1: 0.6449
# Saved new best model at epoch 10 with Macro F1: 0.6733
# Saved new best model at epoch 11 with Macro F1: 0.6782
# Saved new best model at epoch 12 with Macro F1: 0.6876
# Saved new best model at epoch 13 with Macro F1: 0.6905
# Saved new best model at epoch 15 with Macro F1: 0.6977
# Saved new best model at epoch 17 with Macro F1: 0.7067
# Saved new best model at epoch 18 with Macro F1: 0.7181
# Saved new best model at epoch 20 with Macro F1: 0.7190
# Saved new best model at epoch 22 with Macro F1: 0.7245
# Saved new best model at epoch 24 with Macro F1: 0.7277
# Saved new best model at epoch 28 with Macro F1: 0.7287
# Saved new best model at epoch 29 with Macro F1: 0.7320
# Saved new best model at epoch 30 with Macro F1: 0.7439
# Saved new best model at epoch 38 with Macro F1: 0.7518
# Saved new best model at epoch 42 with Macro F1: 0.7538
# Saved new best model at epoch 43 with Macro F1: 0.7594
# Saved new best model at epoch 45 with Macro F1: 0.7678
# Saved new best model at epoch 54 with Macro F1: 0.7707
# Saved new best model at epoch 58 with Macro F1: 0.7762
# Saved new best model at epoch 60 with Macro F1: 0.7917
#
# --- Fold 5/5 ---
# Saved new best model at epoch 1 with Macro F1: 0.2607
# Saved new best model at epoch 2 with Macro F1: 0.3582
# Saved new best model at epoch 3 with Macro F1: 0.4720
# Saved new best model at epoch 4 with Macro F1: 0.5348
# Saved new best model at epoch 5 with Macro F1: 0.5594
# Saved new best model at epoch 6 with Macro F1: 0.6023
# Saved new best model at epoch 7 with Macro F1: 0.6171
# Saved new best model at epoch 8 with Macro F1: 0.6361
# Saved new best model at epoch 9 with Macro F1: 0.6713
# Saved new best model at epoch 10 with Macro F1: 0.6786
# Saved new best model at epoch 11 with Macro F1: 0.6925
# Saved new best model at epoch 12 with Macro F1: 0.7007
# Saved new best model at epoch 14 with Macro F1: 0.7115
# Saved new best model at epoch 18 with Macro F1: 0.7213
# Saved new best model at epoch 20 with Macro F1: 0.7290
# Saved new best model at epoch 21 with Macro F1: 0.7294
# Saved new best model at epoch 22 with Macro F1: 0.7322
# Saved new best model at epoch 25 with Macro F1: 0.7402
# Saved new best model at epoch 26 with Macro F1: 0.7469
# Saved new best model at epoch 28 with Macro F1: 0.7533
# Saved new best model at epoch 31 with Macro F1: 0.7579
# Saved new best model at epoch 33 with Macro F1: 0.7669
# Saved new best model at epoch 34 with Macro F1: 0.7766
# Saved new best model at epoch 37 with Macro F1: 0.7779
# Saved new best model at epoch 39 with Macro F1: 0.7836
# Saved new best model at epoch 44 with Macro F1: 0.7883
# Saved new best model at epoch 47 with Macro F1: 0.7934
# Saved new best model at epoch 51 with Macro F1: 0.7961
# Saved new best model at epoch 52 with Macro F1: 0.7964
# Saved new best model at epoch 56 with Macro F1: 0.7985
# Saved new best model at epoch 59 with Macro F1: 0.7992
# Saved new best model at epoch 60 with Macro F1: 0.8013
# Saved new best model at epoch 61 with Macro F1: 0.8116
# Saved new best model at epoch 78 with Macro F1: 0.8214
# Saved new best model at epoch 80 with Macro F1: 0.8235
# Saved new best model at epoch 85 with Macro F1: 0.8236
# Saved new best model at epoch 89 with Macro F1: 0.8378

# %% [markdown]
# ### Calculating metrics helper function

# %%
# Function to calculate the precision and recall
def calculate_metrics(dataloader, model):
    y_pred = []
    y_true = []
    
    model.eval()
    with torch.no_grad():
        
        # iterate over validation data
        for X, y in dataloader:
            
            X = X.to(torch.float32)
            X = X.to(device)
            output = model(X)  # Feed Network

            output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
            y_pred.extend(output)  # Save Prediction

            labels = y.cpu().numpy()
            y_true.extend(labels)  # Save Truth

    # Calculate confusion matrix
    cf_matrix = confusion_matrix(y_true, y_pred)

    # Calculate precision and recall for each class
    precision = precision_score(y_true, y_pred, average=None, zero_division=0)
    recall = recall_score(y_true, y_pred, average=None, zero_division=0)
    macro_f1 = f1_score(y_true, y_pred, average='macro')
    mcc = matthews_corrcoef(y_true, y_pred)

    return cf_matrix, precision, recall, macro_f1, mcc

# %% [markdown]
# ### Confusion matrix

# %%
# make a function that visualize 5 confusion matrices from 5 data loaders, and stack them into one figure, 3 by 2
def plot_confusion_matrices(cf_matrices, labels, title):
    fig, axes = plt.subplots(2, 3, figsize=(10, 6))
    axes = axes.flatten()
    
    for i, cf_matrix in enumerate(cf_matrices):
        sns.heatmap(cf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
                    xticklabels=labels, yticklabels=labels, ax=axes[i])
        #axes[i].set_xlabel('Predicted')
        #axes[i].set_ylabel('True')
        axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45)
        axes[i].set_title(title[i])
    
    # remove the last empty subplot
    for j in range(i+1, len(axes)):
        fig.delaxes(axes[j])

    # set an overall x and y label for the entire figure
    fig.tight_layout(rect=[0, 0.03, 1, 0.95])  # Adjust layout to make space for the title
    fig.subplots_adjust(hspace=0.4, wspace=0.4)
    fig.text(0.5, 0, 'Predicted', ha='center', fontdict={'size': 16})
    fig.text(0, 0.5, 'True', va='center', rotation='vertical', fontdict={'size': 16})

    #fig.xlabel('Predicted')
    #fig.ylabel('True')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Testing

# %%
model_path
# Out:
# '/home/ec2-user/Jul2025/saved_models/Protein_NN3_unranked_model.pth'

# %%
# Load the model
last_model = PixelPreservingNet(in_channels=3)
last_model.load_state_dict(torch.load(model_path))
last_model.to(device)
# Out:
# PixelPreservingNet(
#   (conv1): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#   )
#   (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv2): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#   )
#   (conv5): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#   )
#   (global_avg_pool): AdaptiveAvgPool2d(output_size=1)
#   (fc1): Sequential(
#     (0): Linear(in_features=256, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.4, inplace=False)
#   )
#   (fc2): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.4, inplace=False)
#   )
#   (output): Linear(in_features=256, out_features=4, bias=True)
# )

# %%
# Read in the synthetic data
# Mertins 
#   proteome
M_PD_synthetic = pd.read_csv(Path(dataset_folder_path+'M_PD_synthetic_kde_june.csv'))
M_PD_synthetic.index = M_PD_synthetic.loc[:,'Unnamed: 0']
M_PD_synthetic = M_PD_synthetic.loc[:, M_PD_synthetic.columns!='Unnamed: 0']

#   transcriptome
M_MD_synthetic = pd.read_csv(Path(dataset_folder_path+'M_MD_synthetic_kde_june.csv'))
M_MD_synthetic.index = M_MD_synthetic.loc[:,'Unnamed: 0']
M_MD_synthetic = M_MD_synthetic.loc[:, M_MD_synthetic.columns!='Unnamed: 0']

# LCSCC tumor
#   proteome
lung_tumor_PD_synthetic = pd.read_csv(Path(dataset_folder_path+'lung_tumor_PD_synthetic_kde_june.csv'))
lung_tumor_PD_synthetic.index = lung_tumor_PD_synthetic.loc[:,'Unnamed: 0']
lung_tumor_PD_synthetic = lung_tumor_PD_synthetic.loc[:, lung_tumor_PD_synthetic.columns!='Unnamed: 0']

#   transcriptome
lung_tumor_MD_synthetic = pd.read_csv(Path(dataset_folder_path+'lung_tumor_MD_synthetic_kde_june.csv'))
lung_tumor_MD_synthetic.index = lung_tumor_MD_synthetic.loc[:,'Unnamed: 0']
lung_tumor_MD_synthetic = lung_tumor_MD_synthetic.loc[:, lung_tumor_MD_synthetic.columns!='Unnamed: 0']

# LCSCC NAT
#   proteome
lung_nat_PD_synthetic = pd.read_csv(Path(dataset_folder_path+'lung_nat_PD_synthetic_kde_june.csv'))
lung_nat_PD_synthetic.index = lung_nat_PD_synthetic.loc[:,'Unnamed: 0']
lung_nat_PD_synthetic = lung_nat_PD_synthetic.loc[:, lung_nat_PD_synthetic.columns!='Unnamed: 0']

#   transcriptome
lung_nat_MD_synthetic = pd.read_csv(Path(dataset_folder_path+'lung_nat_MD_synthetic_kde_june.csv'))
lung_nat_MD_synthetic.index = lung_nat_MD_synthetic.loc[:,'Unnamed: 0']
lung_nat_MD_synthetic = lung_nat_MD_synthetic.loc[:, lung_nat_MD_synthetic.columns!='Unnamed: 0']

# Brain glioma
#   proteome
glioma_PD_synthetic = pd.read_csv(Path(dataset_folder_path+'glioma_tumor_PD_synthetic_kde_june.csv'))
glioma_PD_synthetic.index = glioma_PD_synthetic.loc[:,'gene_name']
glioma_PD_synthetic = glioma_PD_synthetic.loc[:, glioma_PD_synthetic.columns!='gene_name']

#   transcriptome
glioma_MD_synthetic = pd.read_csv(Path(dataset_folder_path+'glioma_tumor_MD_synthetic_kde_june.csv'))
glioma_MD_synthetic.index = glioma_MD_synthetic.loc[:,'gene_name']
glioma_MD_synthetic = glioma_MD_synthetic.loc[:, glioma_MD_synthetic.columns!='gene_name']

# %%
# Breast
# Read in the label
LD_mcf7 = pd.read_csv(Path(label_path+'markers.txt'), sep='\t')
LD_mcf7.index = LD_mcf7.loc[:,'Protein']
LD_mcf7 = LD_mcf7.loc[:,LD_mcf7.columns!='Protein']

# Remove unclassified
NotUnclassInd = LD_mcf7.loc[:,'Localization'] != 'Unclassified'
LD_mcf7 = LD_mcf7.loc[NotUnclassInd,:]

# Lung
LD_h322 = pd.read_csv(Path(label_path+'markers.txt'), sep='\t')
LD_h322.index = LD_h322.loc[:,'Protein']
LD_h322 = LD_h322.loc[:,LD_h322.columns!='Protein']

# Remove unclassified
NotUnclassInd = LD_h322.loc[:,'Localization'] != 'Unclassified'
LD_h322 = LD_h322.loc[NotUnclassInd,:]

# Lung
LD_u251 = pd.read_csv(Path(label_path+'markers.txt'), sep='\t')
LD_u251.index = LD_u251.loc[:,'Protein']
LD_u251 = LD_u251.loc[:,LD_u251.columns!='Protein']

# Remove unclassified
NotUnclassInd = LD_u251.loc[:,'Localization'] != 'Unclassified'
LD_u251 = LD_u251.loc[NotUnclassInd,:]

# %%
M_common_indices = list(set(M_PD_synthetic.index).intersection(set(M_MD_synthetic.index).intersection(set(LD_mcf7.index))))
M_LD = LD_mcf7.loc[LD_mcf7.index.isin(M_common_indices)]
M_PD_synthetic = M_PD_synthetic.loc[M_PD_synthetic.index.isin(M_common_indices)]
M_MD_synthetic = M_MD_synthetic.loc[M_MD_synthetic.index.isin(M_common_indices)]

lung_tumor_common_indices = list(set(lung_tumor_PD_synthetic.index).intersection(set(lung_tumor_MD_synthetic.index).intersection(set(LD_h322.index))))
lung_tumor_LD = LD_h322.loc[LD_h322.index.isin(lung_tumor_common_indices)]
lung_tumor_PD_synthetic = lung_tumor_PD_synthetic.loc[lung_tumor_PD_synthetic.index.isin(lung_tumor_common_indices)]
lung_tumor_MD_synthetic = lung_tumor_MD_synthetic.loc[lung_tumor_MD_synthetic.index.isin(lung_tumor_common_indices)]

lung_nat_common_indices = list(set(lung_nat_PD_synthetic.index).intersection(set(lung_nat_MD_synthetic.index).intersection(set(LD_h322.index))))
lung_nat_LD = LD_h322.loc[LD_h322.index.isin(lung_nat_common_indices)]
lung_nat_PD_synthetic = lung_nat_PD_synthetic.loc[lung_nat_PD_synthetic.index.isin(lung_nat_common_indices)]
lung_nat_MD_synthetic = lung_nat_MD_synthetic.loc[lung_nat_MD_synthetic.index.isin(lung_nat_common_indices)]

glioma_common_indices = list(set(glioma_PD_synthetic.index).intersection(set(glioma_MD_synthetic.index).intersection(set(LD_u251.index))))
glioma_LD = LD_u251.loc[LD_u251.index.isin(glioma_common_indices)]
glioma_PD_synthetic = glioma_PD_synthetic.loc[glioma_PD_synthetic.index.isin(glioma_common_indices)]
glioma_MD_synthetic = glioma_MD_synthetic.loc[glioma_MD_synthetic.index.isin(glioma_common_indices)]

# Convert string labels to integers
M_test_labels = [label_to_int[label] for label in M_LD['Localization'].values]
lung_tumor_test_labels = [label_to_int[label] for label in lung_tumor_LD['Localization'].values]
lung_nat_test_labels = [label_to_int[label] for label in lung_nat_LD['Localization'].values]
glioma_test_labels = [label_to_int[label] for label in glioma_LD['Localization'].values]

# Create the test datasets
if Set == 'Protein':
    M_test_dataset = MyDataset(Set, M_PD_synthetic, M_PD_synthetic, M_PD_synthetic.index, M_test_labels)
    lung_tumor_test_dataset = MyDataset(Set, lung_tumor_PD_synthetic, lung_tumor_PD_synthetic, lung_tumor_PD_synthetic.index, lung_tumor_test_labels)
    lung_nat_test_dataset = MyDataset(Set, lung_nat_PD_synthetic, lung_nat_PD_synthetic, lung_nat_PD_synthetic.index, lung_nat_test_labels)
    glioma_test_dataset = MyDataset(Set, glioma_PD_synthetic, glioma_PD_synthetic, glioma_PD_synthetic.index, glioma_test_labels)
elif Set == 'mRNA':
    M_test_dataset = MyDataset(Set, M_MD_synthetic, M_MD_synthetic, M_MD_synthetic.index, M_test_labels)
    lung_tumor_test_dataset = MyDataset(Set, lung_tumor_MD_synthetic, lung_tumor_MD_synthetic, lung_tumor_MD_synthetic.index, lung_tumor_test_labels)
    lung_nat_test_dataset = MyDataset(Set, lung_nat_MD_synthetic, lung_nat_MD_synthetic, lung_nat_MD_synthetic.index, lung_nat_test_labels)
    glioma_test_dataset = MyDataset(Set, glioma_MD_synthetic, glioma_MD_synthetic, glioma_MD_synthetic.index, glioma_test_labels)
elif Set == 'Protein + mRNA':
    M_test_dataset = MyDataset(Set, M_PD_synthetic, M_MD_synthetic, M_PD_synthetic.index, M_test_labels)
    lung_tumor_test_dataset = MyDataset(Set, lung_tumor_PD_synthetic, lung_tumor_MD_synthetic, lung_tumor_PD_synthetic.index, lung_tumor_test_labels)
    lung_nat_test_dataset = MyDataset(Set, lung_nat_PD_synthetic, lung_nat_MD_synthetic, lung_nat_PD_synthetic.index, lung_nat_test_labels)
    glioma_test_dataset = MyDataset(Set, glioma_PD_synthetic, glioma_MD_synthetic, glioma_PD_synthetic.index, glioma_test_labels)
else:
    raise ValueError("Invalid dataset selection. Choose 'Protein', 'mRNA', 'Protein + mRNA', 'Protein + mRNA Stack'.")

# Create the test data loaders
set_seed(Seed)
M_test_loader = DataLoader(M_test_dataset, batch_size=Batch_size, shuffle=False)
lung_tumor_test_loader = DataLoader(lung_tumor_test_dataset, batch_size=Batch_size, shuffle=False)
lung_nat_test_loader = DataLoader(lung_nat_test_dataset, batch_size=Batch_size, shuffle=False)
glioma_test_loader = DataLoader(glioma_test_dataset, batch_size=Batch_size, shuffle=False)

# %% [markdown]
# ## Metrics

# %% [markdown]
# ### Fig: 5-fold CV

# %%
# Load data
cv_summary_df = pd.read_csv(cv_folder_path + f'{Set}_unranked_5FoldCV_PerClassOnly.csv')

# Setup
class_labels = ['Cytosol', 'Mitochondria', 'Nucleus', 'Secretory']
metrics = ['Precision', 'Recall', 'F1']
metric_columns = {
    'Precision': [f'Precision_C{i}' for i in range(4)],
    'Recall':    [f'Recall_C{i}' for i in range(4)],
    'F1':        [f'F1_C{i}' for i in range(4)],
}

# Construct long-form DataFrame for seaborn
plot_data = []
for metric in metrics:
    for class_idx, class_label in enumerate(class_labels):
        column_name = f"{metric}_C{class_idx}"
        for score in cv_summary_df[column_name].values:
            plot_data.append({
                'Metric': metric,
                'Class': class_label,
                'Score': score
            })

plot_df = pd.DataFrame(plot_data)

# Plot
plt.figure(figsize=(7, 5))
sns.boxplot(data=plot_df, x='Class', y='Score', hue='Metric',
            palette=['#1f77b4', '#ff7f0e', '#d62728'])

# 95% CI values (e.g., mean or reference baseline for each box)
zigzag_y = [0.39428871, 0.39192708, 0.39310435,
            0.1138976, 0.11088505, 0.11237113,
            0.24483776, 0.25053903, 0.24765558,
            0.2973352, 0.29681484, 0.29707479]

# Shading and dashed lines
n_metrics = len(metrics)
box_offsets = np.linspace(-0.25, 0.25, n_metrics)  # for 3 metrics
colors = ['#1f77b4', '#ff7f0e', '#d62728'] * 4  # same as box colors

for class_idx in range(len(class_labels)):
    for metric_idx in range(n_metrics):
        box_idx = class_idx * n_metrics + metric_idx
        x = class_idx + box_offsets[metric_idx]
        y = zigzag_y[box_idx]

        # Dashed line at zigzag_y height
        plt.hlines(y=y, xmin=x - 0.115, xmax=x + 0.115,
                   color='#d62728', linestyle=(0, (5, 5)), linewidth=1)

        # Fill under line with same metric color
        plt.fill_betweenx(y=[0, y], x1=x - 0.115, x2=x + 0.115,
                          color=colors[box_idx], alpha=0.4)

# Add custom legend handle for 95% CI
ci_line = mlines.Line2D([], [], color='#d62728', linestyle=(0, (5, 5)),
                        linewidth=1, label='95% CI')

# Grab existing handles + add 95% CI
handles, labels = plt.gca().get_legend_handles_labels()
handles.append(ci_line)
labels.append("95% CI")

# Finalize legend and labels
plt.legend(handles=handles, labels=labels, title='', fontsize=14,
           frameon=False, loc='upper right')

plt.xlabel('')
plt.ylabel('Score', fontsize=16)
plt.ylim(0, 1.05)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.tight_layout()

plt.savefig(fig_bank_path + f'{Set}_unranked_5foldCV_BoxPlot.pdf', dpi=600, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Fig: training and validation loss and accuracy

# %%
# Find last completed epoch
last_epoch = LossAccDF['Epoch'].max()

fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot loss on left y-axis
ax1.plot(LossAccDF['Epoch'], LossAccDF['TrainLoss'], label='Train Loss', color='tab:blue', linewidth=2)
ax1.plot(LossAccDF['Epoch'], LossAccDF['ValLoss'], label='Val Loss', color='tab:orange', linewidth=2, linestyle='--')
ax1.set_xlabel('Epoch', fontsize=18)
ax1.set_ylabel('Loss', fontsize=16, color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')
ax1.set_xlim([0, last_epoch])
ax1.set_xticks(range(0, last_epoch+1, max(1, last_epoch // 5)))
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.tick_params(axis='both', which='major', labelsize=16)

# Plot accuracy on right y-axis
ax2 = ax1.twinx()
ax2.plot(LossAccDF['Epoch'], LossAccDF['TrainAcc'] * 100, label='Train Acc', color='tab:green', linewidth=2)
ax2.plot(LossAccDF['Epoch'], LossAccDF['ValAcc'] * 100, label='Val Acc', color='tab:red', linewidth=2, linestyle='--')
ax2.set_ylabel('Accuracy (%)', fontsize=16, color='tab:green')
ax2.tick_params(axis='y', labelcolor='tab:green')
ax2.set_ylim([0, 100])

# Combine legends
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, frameon=False, fontsize=16, loc='center left', bbox_to_anchor=(1.15, 0.5))

plt.tight_layout()
plt.savefig(Path(fig_bank_path) / f"{Set}_unranked_Loss_Acc_DualAxis.pdf", dpi=600, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Fig: confusion matrices

# %%
# Set seed
set_seed(Seed)

# Get the confusion matrix and precision and recall for the validation loader and all test loaders
cf_matrix_val, precision_val, recall_val, macro_f1_val, mcc_val = calculate_metrics(val_loader, last_model)
cf_matrix_M, precision_M, recall_M, macro_f1_M, mcc_M = calculate_metrics(M_test_loader, last_model)
cf_matrix_lung_tumor, precision_lung_tumor, recall_lung_tumor, macro_f1_lung_tumor, mcc_lung_tumor = calculate_metrics(lung_tumor_test_loader, last_model)
cf_matrix_lung_nat, precision_lung_nat, recall_lung_nat, macro_f1_lung_nat, mcc_lung_nat = calculate_metrics(lung_nat_test_loader, last_model)
cf_matrix_glioma, precision_glioma, recall_glioma, macro_f1_glioma, mcc_glioma = calculate_metrics(glioma_test_loader, last_model)

# Put them into a list
cf_matrices = [cf_matrix_val, cf_matrix_M, cf_matrix_lung_tumor, cf_matrix_lung_nat, cf_matrix_glioma]
titles = ['Krug Validation', 'Mertins Test ', 'Lung Tumor Test', 'Lung NAT Test', 'Glioma Test']

# Plot the confusion matrices
plot_confusion_matrices(cf_matrices, labels=int_to_label.values(), title=titles)

# Save figure into figure bank
figure3 = plt.gcf()
figure3.savefig(Path(fig_bank_path+Set+'_unranked_Confusion_Matrices.pdf'), dpi=300)

# %% [markdown]
# ### Fig: Precision and recall of validation and testing

# %%
set_seed(Seed)

fig, axes = plt.subplots(2, 2, figsize=(10, 8))
axes = axes.flatten()

compartment_class = ['Cytosol', 'Mitochondria', 'Nucleus', 'Secretory']
colormaps = ['#fc8d62', '#e78ac3', '#8da0cb', '#66c2a5']

for i, f1_score in enumerate(np.array([0.39506494, 0.11058946, 0.24641711, 0.29723098])):
    ax = axes[i]

    # Plot F1 curve
    x_left = np.linspace(0, f1_score / 2, 10000)
    x_right = np.linspace(f1_score / 2, 1, 10000)
    y_right = f1_score * x_right / (2 * x_right - f1_score)
    ax.plot(x_right, y_right, color=colormaps[i], linestyle='--', linewidth=1)
    ax.fill_between(x_left, 0, 1, color=colormaps[i], alpha=0.7)
    ax.fill_between(x_right, 0, y_right, color=colormaps[i], alpha=0.7)

    # Add external test points
    ax.scatter(recall_M[i], precision_M[i], s=75, color='red', edgecolors='red', marker='s', label='Mertins test set')
    ax.scatter(recall_lung_tumor[i], precision_lung_tumor[i], s=75, color='purple', edgecolors='purple', marker='s', label='LSCC Tumor')
    ax.scatter(recall_lung_nat[i], precision_lung_nat[i], s=75, color='orange', edgecolors='orange', marker='s', label='LSCC NAT')
    ax.scatter(recall_glioma[i], precision_glioma[i], s=75, color='green', edgecolors='green', marker='s', label='Glioma')

    # Plot settings
    ax.set_title(compartment_class[i], fontsize=18)
    ax.set_xlim([0, 1])
    ax.set_ylim([0, 1])
    ax.set_xlabel('Recall (Sensitivity)', fontsize=18)
    ax.set_ylabel('Precision\n(Positive Predictive Value)', fontsize=18)
    ax.tick_params(axis='both', labelsize=16)
    ax.grid(True, linestyle='--', alpha=0.4)

    # Remove top and right spines
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    # Legend (only once per subplot)
    mertins_handle = mlines.Line2D([], [], color='red', marker='s', linestyle='None', markersize=8, label='Breast Tumor')
    lung_tumor_handle = mlines.Line2D([], [], color='purple', marker='s', linestyle='None', markersize=8, label='Lung Tumor')
    lung_nat_handle = mlines.Line2D([], [], color='orange', marker='s', linestyle='None', markersize=8, label='Lung NAT')
    glioma_handle = mlines.Line2D([], [], color='green', marker='s', linestyle='None', markersize=8, label='Brain Tumor')

# Global legend outside the subplots
fig.legend(handles=[mertins_handle, lung_tumor_handle, lung_nat_handle, glioma_handle],
           loc='center left', bbox_to_anchor=(1.01, 0.5), fontsize=16, frameon=False)

# Tight layout
plt.tight_layout()  # reserve space on the right

# Save figure at high quality
fig.savefig(Path(fig_bank_path) / f"{Set}_unranked_Precision_Recall_F1curve.pdf", dpi=600, bbox_inches='tight')
# Out:
# /tmp/ipykernel_3389/1528257406.py:15: RuntimeWarning: divide by zero encountered in divide
#   y_right = f1_score * x_right / (2 * x_right - f1_score)

# %%
# export dataframes
LossAccDF.to_excel(Path(fig_bank_path + Set+ f'_unranked_LossAccDF.xlsx'), index=False)
PrecisionRecallDF.to_excel(Path(fig_bank_path + Set+ f'_unranked_PrecisionRecallDF.xlsx'), index=False)
